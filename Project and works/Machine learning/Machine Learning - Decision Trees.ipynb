# %% [markdown]
# ## Trees

# %% [markdown]
# ![Screenshot%202022-06-21%20130224.png](attachment:Screenshot%202022-06-21%20130224.png)

# %% [markdown]
# ![Screenshot%202022-06-21%20130623.png](attachment:Screenshot%202022-06-21%20130623.png)

# %% [markdown]
# ## Decision trees or regression trees

# %% [markdown]
# ![Screenshot%202022-06-20%20222516.png](attachment:Screenshot%202022-06-20%20222516.png)

# %% [markdown]
# ![Screenshot%202022-06-20%20222959.png](attachment:Screenshot%202022-06-20%20222959.png)

# %% [markdown]
# Hours<10 or some number will be chosen such that rss will be low as possible

# %% [markdown]
# ![Screenshot%202022-06-20%20223614.png](attachment:Screenshot%202022-06-20%20223614.png)

# %% [markdown]
# ![Screenshot%202022-06-20%20224500.png](attachment:Screenshot%202022-06-20%20224500.png)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("F:\\Codes\Dataset\\Data Files\\3. ST Academy - Decision Trees resource files\\Movie_regression.csv", header=0)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %% [markdown]
# ## Missing value imputation

# %%
df['Time_taken'].mean()
# Out:
# 157.3914979757085

# %%
df['Time_taken'].fillna(df['Time_taken'].mean(), inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           506 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %% [markdown]
# ## Dummy variable creation

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
df = pd.get_dummies(df, columns =["3D_available", "Genre"], drop_first= True)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %% [markdown]
# ## X-y split

# %%
X = df.loc[ : ,df.columns != "Collection"]
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.shape
# Out:
# (506, 19)

# %%
y = df["Collection"]
type(y)
# Out:
# pandas.core.series.Series

# %%
y.shape
# Out:
# (506,)

# %% [markdown]
# ## Test-Train Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=2, random_state=0)

# %% [markdown]
# ## Training regression tree

# %%
from sklearn import tree

# %%
regtree = tree.DecisionTreeRegressor(max_depth=3)

# %%
regtree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %% [markdown]
# ## Predict values using trained model

# %%
y_train_pred = regtree.predict(X_train)
y_test_pred = regtree.predict(X_test)

# %% [markdown]
# ## Model Performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mean_squared_error(y_test, y_test_pred)
# Out:
# 77899.43526945902

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.8265004338632482

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.9998962392305537

# %% [markdown]
# ## plotting decision tress

# %%
dot_data = tree.export_graphviz(regtree, out_file=None)

# %%
from IPython.display import Image

# %%
import pydotplus

# %%
graph = pydotplus.graph_from_dot_data(dot_data)

# %%
import os

os.environ['PATH'] = os.environ['PATH']+';'+os.environ['CONDA_PREFIX']+r"\Library\bin\graphviz"

# %%
Image(graph.create_png())

# %% [markdown]
# ## Controlling tree growth

# %% [markdown]
# ## Max number of levels in tree

# %%
regtree1 = tree.DecisionTreeRegressor(max_depth=3)
regtree1.fit(X_train, y_train)
dot_data = tree.export_graphviz(regtree1, out_file=None, feature_names= X_train.columns, filled= True)
graph1 = pydotplus.graph_from_dot_data(dot_data)
Image(graph1.create_png())

# %% [markdown]
# ## Minimum observations at internal node

# %%
regtree2 = tree.DecisionTreeRegressor(min_samples_split=40)
regtree2.fit(X_train, y_train)
dot_data = tree.export_graphviz(regtree2, out_file=None, feature_names= X_train.columns, filled= True)
graph1 = pydotplus.graph_from_dot_data(dot_data)
Image(graph1.create_png())

# %% [markdown]
# ## Minimum observations at leaf mode

# %%
regtree3 = tree.DecisionTreeRegressor(min_samples_leaf=25)
regtree3.fit(X_train, y_train)
dot_data = tree.export_graphviz(regtree3, out_file=None, feature_names= X_train.columns, filled= True)
graph1 = pydotplus.graph_from_dot_data(dot_data)
Image(graph1.create_png())

# %% [markdown]
# ## Multiple condition

# %%
regtree3 = tree.DecisionTreeRegressor(min_samples_leaf=25, max_depth= 4)
regtree3.fit(X_train, y_train)
dot_data = tree.export_graphviz(regtree3, out_file=None, feature_names= X_train.columns, filled= True)
graph1 = pydotplus.graph_from_dot_data(dot_data)
Image(graph1.create_png())

# %% [markdown]
# ## Advantages and disadvantages

# %% [markdown]
# ![Screenshot%202022-06-21%20135141.png](attachment:Screenshot%202022-06-21%20135141.png)

# %% [markdown]
# ![Screenshot%202022-06-21%20135141.png](attachment:Screenshot%202022-06-21%20135141.png)

# %% [markdown]
# ![Screenshot%202022-06-21%20135258.png](attachment:Screenshot%202022-06-21%20135258.png)
