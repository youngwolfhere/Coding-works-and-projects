# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Loading the Data and selecting the features

# %%
loan_data_inputs_train = pd.read_csv("F:\\Codes\\Dataset\\Credit analysis\\loan data\\loan_data_inputs_train.csv", index_col=0)
loan_data_inputs_test = pd.read_csv("F:\\Codes\\Dataset\\Credit analysis\\loan data\\loan_data_inputs_test.csv", index_col=0)
loan_data_targets_train = pd.read_csv("F:\\Codes\\Dataset\\Credit analysis\\loan data\\loan_data_targets_train.csv",index_col=0)
loan_data_targets_test = pd.read_csv("F:\\Codes\\Dataset\\Credit analysis\\loan data\\loan_data_targets_test.csv",index_col=0)

# %%
loan_data_inputs_train.head()
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 427211  12796369   14818505      24000        24000          24000.0
# 206088   1439740    1691948      10000        10000          10000.0
# 136020   5214749    6556909      20425        20425          20425.0
# 412305  13827698   15890016      17200        17200          17200.0
# 36159     422455     496525       8400         8400           7450.0
#
#               term  int_rate  installment grade sub_grade  ... dti:21.7-22.4  \
# 427211   36 months      8.90       762.08     A        A5  ...             1
# 206088   36 months     14.33       343.39     C        C1  ...             0
# 136020   36 months      8.90       648.56     A        A5  ...             0
# 412305   36 months     16.59       609.73     D        D1  ...             0
# 36159    36 months     12.84       282.40     C        C2  ...             0
#
#        dti:22.4-35 dti:>35  mths_since_last_record:Missing  \
# 427211           0       0                               1
# 206088           0       0                               1
# 136020           0       0                               1
# 412305           0       0                               1
# 36159            1       0                               1
#
#        mths_since_last_record:0-2 mths_since_last_record:3-20  \
# 427211                          0                           0
# 206088                          0                           0
# 136020                          0                           0
# 412305                          0                           0
# 36159                           0                           0
#
#        mths_since_last_record:21-31 mths_since_last_record:32-80  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#        mths_since_last_record:81-86 mths_since_last_record:>86
# 427211                            0                          0
# 206088                            0                          0
# 136020                            0                          0
# 412305                            0                          0
# 36159                             0                          0
#
# [5 rows x 323 columns]

# %%
loan_data_targets_train.head()
# Out:
#         good_bad
# 427211         1
# 206088         1
# 136020         1
# 412305         0
# 36159          0

# %%
loan_data_inputs_train.shape
# Out:
# (373028, 323)

# %%
loan_data_targets_train.shape
# Out:
# (373028, 1)

# %%
loan_data_inputs_test.shape
# Out:
# (93257, 323)

# %%
loan_data_targets_test.shape
# Out:
# (93257, 1)

# %% [markdown]
# ### Selecting the features

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:sm_bus_edu_mov_hou',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:RE_med_wed_vac',
'purpose:home_imp__maj_pur_car',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<95',
'mths_since_issue_d:95-96',
'mths_since_issue_d:97-98',
'mths_since_issue_d:99-105',
'mths_since_issue_d:106-109',
'mths_since_issue_d:110-121',
'mths_since_issue_d:122-141',
'mths_since_issue_d:>141',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'delinq_2yrs:0',
'delinq_2yrs:1-3',
'delinq_2yrs:>=4',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:0',
'open_acc:1-3',
'open_acc:4-12',
'open_acc:13-17',
'open_acc:18-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'pub_rec:0-2',
'pub_rec:3-4',
'pub_rec:>=5',
'total_acc:<=27',
'total_acc:28-51',
'total_acc:>=52',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>86']]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:sm_bus_edu_mov_hou',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>141',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'delinq_2yrs:>=4',
'inq_last_6mths:>6',
'open_acc:0',
'pub_rec:0-2',
'total_acc:<=27',
'acc_now_delinq:0',
'total_rev_hi_lim:<=5K',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211              0  ...                               1
# 206088              0  ...                               0
# 136020              0  ...                               0
# 412305              0  ...                               0
# 36159               0  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>86
# 427211                           0
# 206088                           0
# 136020                           0
# 412305                           0
# 36159                            0
#
# [5 rows x 104 columns]

# %% [markdown]
# ### PD Model Estimation

# %% [markdown]
# #### Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()

# %%
pd.options.display.max_rows = None

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\sathi\anaconda3\envs\r4-anaconda\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sathi\anaconda3\envs\r4-anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
reg.intercept_
# Out:
# array([-1.36421233])

# %%
reg.coef_
# Out:
# array([[ 1.17465653e+00,  9.13461899e-01,  7.16070145e-01,
#          5.25081567e-01,  3.42099547e-01,  1.48451014e-01,
#          9.55338116e-02,  1.09854408e-01,  3.63168602e-02,
#          5.84757458e-02,  5.72438004e-02,  6.16158730e-02,
#          7.63580930e-02,  1.34337386e-01,  9.96147503e-02,
#          1.82655936e-01,  2.26601485e-01,  2.23052639e-01,
#          2.60856129e-01,  3.17363441e-01,  5.21390939e-01,
#          8.82765872e-02, -1.20248195e-02,  2.04930498e-01,
#          1.01104102e-01,  1.94183095e-01,  1.66043951e-01,
#          5.42577786e-02,  7.76972644e-02,  9.72170310e-02,
#          1.21803275e-01,  8.67917170e-02,  5.81685987e-02,
#          1.24661864e-01,  1.08493194e+00,  8.83956170e-01,
#          7.82187858e-01,  5.78489225e-01,  4.15765335e-01,
#          1.67489111e-01, -7.33836570e-02,  8.41918674e-01,
#          5.35928749e-01,  2.86781268e-01,  9.90140540e-02,
#          6.54743960e-02,  1.39551168e-01,  1.34291262e-01,
#          1.71440506e-01,  2.15416484e-01,  7.03339322e-02,
#          2.83795505e-02,  6.53570522e-01,  5.09716022e-01,
#          2.99336349e-01, -1.30363070e-02, -1.11956938e-01,
#         -1.38404593e-01, -1.53456298e-01, -1.61008814e-01,
#         -1.27041502e-01, -2.15952477e-01,  1.21216862e-01,
#          1.82890912e-01, -1.83486937e-02,  2.59525476e-02,
#          2.14967709e-01,  3.29585014e-02,  6.44188060e-04,
#         -9.16452104e-04,  1.39111521e-02,  3.57676993e-02,
#          6.10000180e-02,  2.05629909e-01, -5.73960094e-02,
#          1.03011177e-02,  1.06989936e-01,  1.75463667e-01,
#          2.50666518e-01,  3.24192453e-01,  4.00696868e-01,
#          4.20323612e-01,  4.97475270e-01,  5.83859796e-01,
#          5.10946790e-01,  1.97774144e-01,  3.33832583e-01,
#          3.61522986e-01,  3.03408671e-01,  2.29186059e-01,
#          1.31670400e-01,  1.19997378e-01,  8.81595137e-02,
#          4.69938433e-02,  7.90016182e-02,  1.48336759e-01,
#          1.59170871e-01,  1.11345311e-01,  3.52806791e-01,
#          4.49051930e-01,  3.78359200e-01,  5.42059946e-01,
#          2.12129584e-01,  2.68851820e-01]])

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ["Feature name"],data = feature_name)
summary_table["Coefficients"] = np.transpose(reg.coef_)
summary_table
# Out:
#                             Feature name  Coefficients
# 0                                grade:A      1.174657
# 1                                grade:B      0.913462
# 2                                grade:C      0.716070
# 3                                grade:D      0.525082
# 4                                grade:E      0.342100
# 5                                grade:F      0.148451
# 6                     home_ownership:OWN      0.095534
# 7                home_ownership:MORTGAGE      0.109854
# 8                       addr_state:NM_VA      0.036317
# 9                          addr_state:NY      0.058476
# 10          addr_state:OK_TN_MO_LA_MD_NC      0.057244
# 11                         addr_state:CA      0.061616
# 12                addr_state:UT_KY_AZ_NJ      0.076358
# 13             addr_state:AR_MI_PA_OH_MN      0.134337
# 14             addr_state:RI_MA_DE_SD_IN      0.099615
# 15                   addr_state:GA_WA_OR      0.182656
# 16                      addr_state:WI_MT      0.226601
# 17                         addr_state:TX      0.223053
# 18                      addr_state:IL_CT      0.260856
# 19          addr_state:KS_SC_CO_VT_AK_MS      0.317363
# 20          addr_state:WV_NH_WY_DC_ME_ID      0.521391
# 21      verification_status:Not Verified      0.088277
# 22   verification_status:Source Verified     -0.012025
# 23                   purpose:credit_card      0.204930
# 24            purpose:debt_consolidation      0.101104
# 25                purpose:RE_med_wed_vac      0.194183
# 26         purpose:home_imp__maj_pur_car      0.166044
# 27                 initial_list_status:w      0.054258
# 28                               term:36      0.077697
# 29                          emp_length:1      0.097217
# 30                        emp_length:2-4      0.121803
# 31                        emp_length:5-6      0.086792
# 32                        emp_length:7-9      0.058169
# 33                         emp_length:10      0.124662
# 34                mths_since_issue_d:<95      1.084932
# 35              mths_since_issue_d:95-96      0.883956
# 36              mths_since_issue_d:97-98      0.782188
# 37             mths_since_issue_d:99-105      0.578489
# 38            mths_since_issue_d:106-109      0.415765
# 39            mths_since_issue_d:110-121      0.167489
# 40            mths_since_issue_d:122-141     -0.073384
# 41                       int_rate:<9.548      0.841919
# 42                 int_rate:9.548-12.025      0.535929
# 43                 int_rate:12.025-15.74      0.286781
# 44                 int_rate:15.74-20.281      0.099014
# 45   mths_since_earliest_cr_line:141-164      0.065474
# 46   mths_since_earliest_cr_line:165-247      0.139551
# 47   mths_since_earliest_cr_line:248-270      0.134291
# 48   mths_since_earliest_cr_line:271-352      0.171441
# 49      mths_since_earliest_cr_line:>352      0.215416
# 50                         delinq_2yrs:0      0.070334
# 51                       delinq_2yrs:1-3      0.028380
# 52                      inq_last_6mths:0      0.653571
# 53                    inq_last_6mths:1-2      0.509716
# 54                    inq_last_6mths:3-6      0.299336
# 55                          open_acc:1-3     -0.013036
# 56                         open_acc:4-12     -0.111957
# 57                        open_acc:13-17     -0.138405
# 58                        open_acc:18-22     -0.153456
# 59                        open_acc:23-25     -0.161009
# 60                        open_acc:26-30     -0.127042
# 61                         open_acc:>=31     -0.215952
# 62                           pub_rec:3-4      0.121217
# 63                           pub_rec:>=5      0.182891
# 64                       total_acc:28-51     -0.018349
# 65                        total_acc:>=52      0.025953
# 66                    acc_now_delinq:>=1      0.214968
# 67               total_rev_hi_lim:5K-10K      0.032959
# 68              total_rev_hi_lim:10K-20K      0.000644
# 69              total_rev_hi_lim:20K-30K     -0.000916
# 70              total_rev_hi_lim:30K-40K      0.013911
# 71              total_rev_hi_lim:40K-55K      0.035768
# 72              total_rev_hi_lim:55K-95K      0.061000
# 73                 total_rev_hi_lim:>95K      0.205630
# 74                    annual_inc:20K-30K     -0.057396
# 75                    annual_inc:30K-40K      0.010301
# 76                    annual_inc:40K-50K      0.106990
# 77                    annual_inc:50K-60K      0.175464
# 78                    annual_inc:60K-70K      0.250667
# 79                    annual_inc:70K-80K      0.324192
# 80                    annual_inc:80K-90K      0.400697
# 81                   annual_inc:90K-100K      0.420324
# 82                  annual_inc:100K-120K      0.497475
# 83                  annual_inc:120K-140K      0.583860
# 84                      annual_inc:>140K      0.510947
# 85                             dti:<=1.4      0.197774
# 86                           dti:1.4-3.5      0.333833
# 87                           dti:3.5-7.7      0.361523
# 88                          dti:7.7-10.5      0.303409
# 89                         dti:10.5-16.1      0.229186
# 90                         dti:16.1-20.3      0.131670
# 91                         dti:20.3-21.7      0.119997
# 92                         dti:21.7-22.4      0.088160
# 93                           dti:22.4-35      0.046994
# 94        mths_since_last_delinq:Missing      0.079002
# 95           mths_since_last_delinq:4-30      0.148337
# 96          mths_since_last_delinq:31-56      0.159171
# 97           mths_since_last_delinq:>=57      0.111345
# 98        mths_since_last_record:Missing      0.352807
# 99           mths_since_last_record:3-20      0.449052
# 100         mths_since_last_record:21-31      0.378359
# 101         mths_since_last_record:32-80      0.542060
# 102         mths_since_last_record:81-86      0.212130
# 103           mths_since_last_record:>86      0.268852

# %%
# adding intercept as well
summary_table.index = summary_table.index +1
summary_table.loc[0]=["Intercept", reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept     -1.364212
# 1                                grade:A      1.174657
# 2                                grade:B      0.913462
# 3                                grade:C      0.716070
# 4                                grade:D      0.525082
# 5                                grade:E      0.342100
# 6                                grade:F      0.148451
# 7                     home_ownership:OWN      0.095534
# 8                home_ownership:MORTGAGE      0.109854
# 9                       addr_state:NM_VA      0.036317
# 10                         addr_state:NY      0.058476
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.057244
# 12                         addr_state:CA      0.061616
# 13                addr_state:UT_KY_AZ_NJ      0.076358
# 14             addr_state:AR_MI_PA_OH_MN      0.134337
# 15             addr_state:RI_MA_DE_SD_IN      0.099615
# 16                   addr_state:GA_WA_OR      0.182656
# 17                      addr_state:WI_MT      0.226601
# 18                         addr_state:TX      0.223053
# 19                      addr_state:IL_CT      0.260856
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.317363
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.521391
# 22      verification_status:Not Verified      0.088277
# 23   verification_status:Source Verified     -0.012025
# 24                   purpose:credit_card      0.204930
# 25            purpose:debt_consolidation      0.101104
# 26                purpose:RE_med_wed_vac      0.194183
# 27         purpose:home_imp__maj_pur_car      0.166044
# 28                 initial_list_status:w      0.054258
# 29                               term:36      0.077697
# 30                          emp_length:1      0.097217
# 31                        emp_length:2-4      0.121803
# 32                        emp_length:5-6      0.086792
# 33                        emp_length:7-9      0.058169
# 34                         emp_length:10      0.124662
# 35                mths_since_issue_d:<95      1.084932
# 36              mths_since_issue_d:95-96      0.883956
# 37              mths_since_issue_d:97-98      0.782188
# 38             mths_since_issue_d:99-105      0.578489
# 39            mths_since_issue_d:106-109      0.415765
# 40            mths_since_issue_d:110-121      0.167489
# 41            mths_since_issue_d:122-141     -0.073384
# 42                       int_rate:<9.548      0.841919
# 43                 int_rate:9.548-12.025      0.535929
# 44                 int_rate:12.025-15.74      0.286781
# 45                 int_rate:15.74-20.281      0.099014
# 46   mths_since_earliest_cr_line:141-164      0.065474
# 47   mths_since_earliest_cr_line:165-247      0.139551
# 48   mths_since_earliest_cr_line:248-270      0.134291
# 49   mths_since_earliest_cr_line:271-352      0.171441
# 50      mths_since_earliest_cr_line:>352      0.215416
# 51                         delinq_2yrs:0      0.070334
# 52                       delinq_2yrs:1-3      0.028380
# 53                      inq_last_6mths:0      0.653571
# 54                    inq_last_6mths:1-2      0.509716
# 55                    inq_last_6mths:3-6      0.299336
# 56                          open_acc:1-3     -0.013036
# 57                         open_acc:4-12     -0.111957
# 58                        open_acc:13-17     -0.138405
# 59                        open_acc:18-22     -0.153456
# 60                        open_acc:23-25     -0.161009
# 61                        open_acc:26-30     -0.127042
# 62                         open_acc:>=31     -0.215952
# 63                           pub_rec:3-4      0.121217
# 64                           pub_rec:>=5      0.182891
# 65                       total_acc:28-51     -0.018349
# 66                        total_acc:>=52      0.025953
# 67                    acc_now_delinq:>=1      0.214968
# 68               total_rev_hi_lim:5K-10K      0.032959
# 69              total_rev_hi_lim:10K-20K      0.000644
# 70              total_rev_hi_lim:20K-30K     -0.000916
# 71              total_rev_hi_lim:30K-40K      0.013911
# 72              total_rev_hi_lim:40K-55K      0.035768
# 73              total_rev_hi_lim:55K-95K      0.061000
# 74                 total_rev_hi_lim:>95K      0.205630
# 75                    annual_inc:20K-30K     -0.057396
# 76                    annual_inc:30K-40K      0.010301
# 77                    annual_inc:40K-50K      0.106990
# 78                    annual_inc:50K-60K      0.175464
# 79                    annual_inc:60K-70K      0.250667
# 80                    annual_inc:70K-80K      0.324192
# 81                    annual_inc:80K-90K      0.400697
# 82                   annual_inc:90K-100K      0.420324
# 83                  annual_inc:100K-120K      0.497475
# 84                  annual_inc:120K-140K      0.583860
# 85                      annual_inc:>140K      0.510947
# 86                             dti:<=1.4      0.197774
# 87                           dti:1.4-3.5      0.333833
# 88                           dti:3.5-7.7      0.361523
# 89                          dti:7.7-10.5      0.303409
# 90                         dti:10.5-16.1      0.229186
# 91                         dti:16.1-20.3      0.131670
# 92                         dti:20.3-21.7      0.119997
# 93                         dti:21.7-22.4      0.088160
# 94                           dti:22.4-35      0.046994
# 95        mths_since_last_delinq:Missing      0.079002
# 96           mths_since_last_delinq:4-30      0.148337
# 97          mths_since_last_delinq:31-56      0.159171
# 98           mths_since_last_delinq:>=57      0.111345
# 99        mths_since_last_record:Missing      0.352807
# 100          mths_since_last_record:3-20      0.449052
# 101         mths_since_last_record:21-31      0.378359
# 102         mths_since_last_record:32-80      0.542060
# 103         mths_since_last_record:81-86      0.212130
# 104           mths_since_last_record:>86      0.268852

# %% [markdown]
# ### Build a logistic regression Model with P-values

# %% [markdown]
# Built in p values funtion of sk learn is univariate. So we will make our new p values of every variable together

# %%
from sklearn import linear_model
import scipy.stats as stat

# %%
class LogisticRegression_with_p_values:
    def __init__(self,*args, **kwargs):
        self.model = linear_model.LogisticRegression(*args, **kwargs)
    
    def fit(self,X,y):
        self.model.fit(X,y)
        
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X) # Fisher Information Matrix
        Cramer_Rao = np.linalg.inv(F_ij) # Inverse Information Matrix
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates #z-score for each model coefficient
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores] #two tailed test for p-values
        
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
reg = LogisticRegression_with_p_values()

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\sathi\anaconda3\envs\r4-anaconda\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sathi\anaconda3\envs\r4-anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
p_values = reg.p_values

# %% [markdown]
# p values doesnt have coeff for intercept. So we will add Nan for intercept term

# %%
p_values = np.append(np.nan, np.array(p_values))

# %%
summary_table['p_values'] = p_values

# %%
pd.options.display.float_format = '{:.4f}'.format
summary_table
# Out:
#                             Feature name  Coefficients  p_values
# 0                              Intercept       -1.3642       NaN
# 1                                grade:A        1.1747    0.0000
# 2                                grade:B        0.9135    0.0000
# 3                                grade:C        0.7161    0.0000
# 4                                grade:D        0.5251    0.0000
# 5                                grade:E        0.3421    0.0000
# 6                                grade:F        0.1485    0.0031
# 7                     home_ownership:OWN        0.0955    0.0000
# 8                home_ownership:MORTGAGE        0.1099    0.0000
# 9                       addr_state:NM_VA        0.0363    0.2576
# 10                         addr_state:NY        0.0585    0.0161
# 11          addr_state:OK_TN_MO_LA_MD_NC        0.0572    0.0137
# 12                         addr_state:CA        0.0616    0.0037
# 13                addr_state:UT_KY_AZ_NJ        0.0764    0.0022
# 14             addr_state:AR_MI_PA_OH_MN        0.1343    0.0000
# 15             addr_state:RI_MA_DE_SD_IN        0.0996    0.0009
# 16                   addr_state:GA_WA_OR        0.1827    0.0000
# 17                      addr_state:WI_MT        0.2266    0.0000
# 18                         addr_state:TX        0.2231    0.0000
# 19                      addr_state:IL_CT        0.2609    0.0000
# 20          addr_state:KS_SC_CO_VT_AK_MS        0.3174    0.0000
# 21          addr_state:WV_NH_WY_DC_ME_ID        0.5214    0.0000
# 22      verification_status:Not Verified        0.0883    0.0000
# 23   verification_status:Source Verified       -0.0120    0.3722
# 24                   purpose:credit_card        0.2049    0.0000
# 25            purpose:debt_consolidation        0.1011    0.0000
# 26                purpose:RE_med_wed_vac        0.1942    0.0000
# 27         purpose:home_imp__maj_pur_car        0.1660    0.0000
# 28                 initial_list_status:w        0.0543    0.0000
# 29                               term:36        0.0777    0.0000
# 30                          emp_length:1        0.0972    0.0002
# 31                        emp_length:2-4        0.1218    0.0000
# 32                        emp_length:5-6        0.0868    0.0001
# 33                        emp_length:7-9        0.0582    0.0052
# 34                         emp_length:10        0.1247    0.0000
# 35                mths_since_issue_d:<95        1.0849    0.0000
# 36              mths_since_issue_d:95-96        0.8840    0.0000
# 37              mths_since_issue_d:97-98        0.7822    0.0000
# 38             mths_since_issue_d:99-105        0.5785    0.0000
# 39            mths_since_issue_d:106-109        0.4158    0.0000
# 40            mths_since_issue_d:110-121        0.1675    0.0000
# 41            mths_since_issue_d:122-141       -0.0734    0.0123
# 42                       int_rate:<9.548        0.8419    0.0000
# 43                 int_rate:9.548-12.025        0.5359    0.0000
# 44                 int_rate:12.025-15.74        0.2868    0.0000
# 45                 int_rate:15.74-20.281        0.0990    0.0007
# 46   mths_since_earliest_cr_line:141-164        0.0655    0.4640
# 47   mths_since_earliest_cr_line:165-247        0.1396    0.0785
# 48   mths_since_earliest_cr_line:248-270        0.1343    0.0933
# 49   mths_since_earliest_cr_line:271-352        0.1714    0.0309
# 50      mths_since_earliest_cr_line:>352        0.2154    0.0070
# 51                         delinq_2yrs:0        0.0703    0.2182
# 52                       delinq_2yrs:1-3        0.0284    0.5974
# 53                      inq_last_6mths:0        0.6536    0.0000
# 54                    inq_last_6mths:1-2        0.5097    0.0000
# 55                    inq_last_6mths:3-6        0.2993    0.0093
# 56                          open_acc:1-3       -0.0130    0.9426
# 57                         open_acc:4-12       -0.1120    0.5285
# 58                        open_acc:13-17       -0.1384    0.4368
# 59                        open_acc:18-22       -0.1535    0.3912
# 60                        open_acc:23-25       -0.1610    0.3795
# 61                        open_acc:26-30       -0.1270    0.4995
# 62                         open_acc:>=31       -0.2160    0.2824
# 63                           pub_rec:3-4        0.1212    0.2011
# 64                           pub_rec:>=5        0.1829    0.3438
# 65                       total_acc:28-51       -0.0183    0.1966
# 66                        total_acc:>=52        0.0260    0.5136
# 67                    acc_now_delinq:>=1        0.2150    0.0436
# 68               total_rev_hi_lim:5K-10K        0.0330    0.1813
# 69              total_rev_hi_lim:10K-20K        0.0006    0.9785
# 70              total_rev_hi_lim:20K-30K       -0.0009    0.9722
# 71              total_rev_hi_lim:30K-40K        0.0139    0.6368
# 72              total_rev_hi_lim:40K-55K        0.0358    0.2664
# 73              total_rev_hi_lim:55K-95K        0.0610    0.0907
# 74                 total_rev_hi_lim:>95K        0.2056    0.0003
# 75                    annual_inc:20K-30K       -0.0574    0.1807
# 76                    annual_inc:30K-40K        0.0103    0.8033
# 77                    annual_inc:40K-50K        0.1070    0.0097
# 78                    annual_inc:50K-60K        0.1755    0.0000
# 79                    annual_inc:60K-70K        0.2507    0.0000
# 80                    annual_inc:70K-80K        0.3242    0.0000
# 81                    annual_inc:80K-90K        0.4007    0.0000
# 82                   annual_inc:90K-100K        0.4203    0.0000
# 83                  annual_inc:100K-120K        0.4975    0.0000
# 84                  annual_inc:120K-140K        0.5839    0.0000
# 85                      annual_inc:>140K        0.5109    0.0000
# 86                             dti:<=1.4        0.1978    0.0252
# 87                           dti:1.4-3.5        0.3338    0.0000
# 88                           dti:3.5-7.7        0.3615    0.0000
# 89                          dti:7.7-10.5        0.3034    0.0000
# 90                         dti:10.5-16.1        0.2292    0.0003
# 91                         dti:16.1-20.3        0.1317    0.0356
# 92                         dti:20.3-21.7        0.1200    0.0653
# 93                         dti:21.7-22.4        0.0882    0.2008
# 94                           dti:22.4-35        0.0470    0.4477
# 95        mths_since_last_delinq:Missing        0.0790    0.1688
# 96           mths_since_last_delinq:4-30        0.1483    0.0052
# 97          mths_since_last_delinq:31-56        0.1592    0.0065
# 98           mths_since_last_delinq:>=57        0.1113    0.0619
# 99        mths_since_last_record:Missing        0.3528    0.0000
# 100          mths_since_last_record:3-20        0.4491    0.0004
# 101         mths_since_last_record:21-31        0.3784    0.0012
# 102         mths_since_last_record:32-80        0.5421    0.0000
# 103         mths_since_last_record:81-86        0.2121    0.0454
# 104           mths_since_last_record:>86        0.2689    0.0024

# %% [markdown]
# ##### P values less than 0.05 says that the particular dummy is statistically significant. As each independent variable is  represented by many dummies, we will keep it only if atleast one of the category dummies are statistically significant.(if we remove the insignificant ones and keep the significant ones only, it will represent only the part of independent variable. So, its ideal to keep them).

# %% [markdown]
# ### Running a reg again on only significant independent variables

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:sm_bus_edu_mov_hou',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:RE_med_wed_vac',
'purpose:home_imp__maj_pur_car',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<95',
'mths_since_issue_d:95-96',
'mths_since_issue_d:97-98',
'mths_since_issue_d:99-105',
'mths_since_issue_d:106-109',
'mths_since_issue_d:110-121',
'mths_since_issue_d:122-141',
'mths_since_issue_d:>141',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>86'
]]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:sm_bus_edu_mov_hou',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>141',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211              0  ...                               1
# 206088              0  ...                               0
# 136020              0  ...                               0
# 412305              0  ...                               0
# 36159               0  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>86
# 427211                           0
# 206088                           0
# 136020                           0
# 412305                           0
# 36159                            0
#
# [5 rows x 84 columns]

# %%
reg2 = LogisticRegression_with_p_values()
reg2.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\sathi\anaconda3\envs\r4-anaconda\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\sathi\anaconda3\envs\r4-anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg2.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept       -1.4247
# 1                               grade:A        1.1410
# 2                               grade:B        0.8952
# 3                               grade:C        0.6996
# 4                               grade:D        0.5104
# 5                               grade:E        0.3328
# 6                               grade:F        0.1442
# 7                    home_ownership:OWN        0.0979
# 8               home_ownership:MORTGAGE        0.1093
# 9                      addr_state:NM_VA        0.0369
# 10                        addr_state:NY        0.0563
# 11         addr_state:OK_TN_MO_LA_MD_NC        0.0569
# 12                        addr_state:CA        0.0620
# 13               addr_state:UT_KY_AZ_NJ        0.0760
# 14            addr_state:AR_MI_PA_OH_MN        0.1332
# 15            addr_state:RI_MA_DE_SD_IN        0.0980
# 16                  addr_state:GA_WA_OR        0.1836
# 17                     addr_state:WI_MT        0.2343
# 18                        addr_state:TX        0.2203
# 19                     addr_state:IL_CT        0.2597
# 20         addr_state:KS_SC_CO_VT_AK_MS        0.3194
# 21         addr_state:WV_NH_WY_DC_ME_ID        0.5177
# 22     verification_status:Not Verified        0.0870
# 23  verification_status:Source Verified       -0.0116
# 24                  purpose:credit_card        0.2020
# 25           purpose:debt_consolidation        0.0986
# 26               purpose:RE_med_wed_vac        0.2009
# 27        purpose:home_imp__maj_pur_car        0.1663
# 28                initial_list_status:w        0.0542
# 29                              term:36        0.0773
# 30                         emp_length:1        0.0956
# 31                       emp_length:2-4        0.1215
# 32                       emp_length:5-6        0.0874
# 33                       emp_length:7-9        0.0586
# 34                        emp_length:10        0.1268
# 35               mths_since_issue_d:<95        1.0871
# 36             mths_since_issue_d:95-96        0.8822
# 37             mths_since_issue_d:97-98        0.7806
# 38            mths_since_issue_d:99-105        0.5787
# 39           mths_since_issue_d:106-109        0.4171
# 40           mths_since_issue_d:110-121        0.1678
# 41           mths_since_issue_d:122-141       -0.0780
# 42                      int_rate:<9.548        0.8774
# 43                int_rate:9.548-12.025        0.5528
# 44                int_rate:12.025-15.74        0.3012
# 45                int_rate:15.74-20.281        0.1104
# 46  mths_since_earliest_cr_line:141-164        0.0729
# 47  mths_since_earliest_cr_line:165-247        0.1426
# 48  mths_since_earliest_cr_line:248-270        0.1368
# 49  mths_since_earliest_cr_line:271-352        0.1750
# 50     mths_since_earliest_cr_line:>352        0.2215
# 51                     inq_last_6mths:0        0.6819
# 52                   inq_last_6mths:1-2        0.5345
# 53                   inq_last_6mths:3-6        0.3235
# 54                   acc_now_delinq:>=1        0.1826
# 55                   annual_inc:20K-30K       -0.0783
# 56                   annual_inc:30K-40K       -0.0171
# 57                   annual_inc:40K-50K        0.0771
# 58                   annual_inc:50K-60K        0.1436
# 59                   annual_inc:60K-70K        0.2193
# 60                   annual_inc:70K-80K        0.2927
# 61                   annual_inc:80K-90K        0.3706
# 62                  annual_inc:90K-100K        0.3892
# 63                 annual_inc:100K-120K        0.4668
# 64                 annual_inc:120K-140K        0.5570
# 65                     annual_inc:>140K        0.4956
# 66                            dti:<=1.4        0.2463
# 67                          dti:1.4-3.5        0.3694
# 68                          dti:3.5-7.7        0.3876
# 69                         dti:7.7-10.5        0.3244
# 70                        dti:10.5-16.1        0.2466
# 71                        dti:16.1-20.3        0.1461
# 72                        dti:20.3-21.7        0.1327
# 73                        dti:21.7-22.4        0.1021
# 74                          dti:22.4-35        0.0573
# 75       mths_since_last_delinq:Missing        0.1113
# 76          mths_since_last_delinq:4-30        0.1406
# 77         mths_since_last_delinq:31-56        0.1863
# 78          mths_since_last_delinq:>=57        0.1392
# 79       mths_since_last_record:Missing        0.3326
# 80          mths_since_last_record:3-20        0.4515
# 81         mths_since_last_record:21-31        0.3614
# 82         mths_since_last_record:32-80        0.5188
# 83         mths_since_last_record:81-86        0.1886
# 84           mths_since_last_record:>86        0.2463

# %%
p_values = reg2.p_values
p_values = np.append(np.nan,np.array(p_values))
summary_table['p_values'] = p_values
summary_table
# Out:
#                            Feature name  Coefficients  p_values
# 0                             Intercept       -1.4247       NaN
# 1                               grade:A        1.1410    0.0000
# 2                               grade:B        0.8952    0.0000
# 3                               grade:C        0.6996    0.0000
# 4                               grade:D        0.5104    0.0000
# 5                               grade:E        0.3328    0.0000
# 6                               grade:F        0.1442    0.0034
# 7                    home_ownership:OWN        0.0979    0.0000
# 8               home_ownership:MORTGAGE        0.1093    0.0000
# 9                      addr_state:NM_VA        0.0369    0.2489
# 10                        addr_state:NY        0.0563    0.0201
# 11         addr_state:OK_TN_MO_LA_MD_NC        0.0569    0.0140
# 12                        addr_state:CA        0.0620    0.0035
# 13               addr_state:UT_KY_AZ_NJ        0.0760    0.0023
# 14            addr_state:AR_MI_PA_OH_MN        0.1332    0.0000
# 15            addr_state:RI_MA_DE_SD_IN        0.0980    0.0010
# 16                  addr_state:GA_WA_OR        0.1836    0.0000
# 17                     addr_state:WI_MT        0.2343    0.0000
# 18                        addr_state:TX        0.2203    0.0000
# 19                     addr_state:IL_CT        0.2597    0.0000
# 20         addr_state:KS_SC_CO_VT_AK_MS        0.3194    0.0000
# 21         addr_state:WV_NH_WY_DC_ME_ID        0.5177    0.0000
# 22     verification_status:Not Verified        0.0870    0.0000
# 23  verification_status:Source Verified       -0.0116    0.3871
# 24                  purpose:credit_card        0.2020    0.0000
# 25           purpose:debt_consolidation        0.0986    0.0000
# 26               purpose:RE_med_wed_vac        0.2009    0.0000
# 27        purpose:home_imp__maj_pur_car        0.1663    0.0000
# 28                initial_list_status:w        0.0542    0.0000
# 29                              term:36        0.0773    0.0000
# 30                         emp_length:1        0.0956    0.0002
# 31                       emp_length:2-4        0.1215    0.0000
# 32                       emp_length:5-6        0.0874    0.0000
# 33                       emp_length:7-9        0.0586    0.0049
# 34                        emp_length:10        0.1268    0.0000
# 35               mths_since_issue_d:<95        1.0871    0.0000
# 36             mths_since_issue_d:95-96        0.8822    0.0000
# 37             mths_since_issue_d:97-98        0.7806    0.0000
# 38            mths_since_issue_d:99-105        0.5787    0.0000
# 39           mths_since_issue_d:106-109        0.4171    0.0000
# 40           mths_since_issue_d:110-121        0.1678    0.0000
# 41           mths_since_issue_d:122-141       -0.0780    0.0077
# 42                      int_rate:<9.548        0.8774    0.0000
# 43                int_rate:9.548-12.025        0.5528    0.0000
# 44                int_rate:12.025-15.74        0.3012    0.0000
# 45                int_rate:15.74-20.281        0.1104    0.0001
# 46  mths_since_earliest_cr_line:141-164        0.0729    0.3726
# 47  mths_since_earliest_cr_line:165-247        0.1426    0.0429
# 48  mths_since_earliest_cr_line:248-270        0.1368    0.0548
# 49  mths_since_earliest_cr_line:271-352        0.1750    0.0131
# 50     mths_since_earliest_cr_line:>352        0.2215    0.0018
# 51                     inq_last_6mths:0        0.6819    0.0000
# 52                   inq_last_6mths:1-2        0.5345    0.0000
# 53                   inq_last_6mths:3-6        0.3235    0.0006
# 54                   acc_now_delinq:>=1        0.1826    0.0845
# 55                   annual_inc:20K-30K       -0.0783    0.0635
# 56                   annual_inc:30K-40K       -0.0171    0.6730
# 57                   annual_inc:40K-50K        0.0771    0.0567
# 58                   annual_inc:50K-60K        0.1436    0.0005
# 59                   annual_inc:60K-70K        0.2193    0.0000
# 60                   annual_inc:70K-80K        0.2927    0.0000
# 61                   annual_inc:80K-90K        0.3706    0.0000
# 62                  annual_inc:90K-100K        0.3892    0.0000
# 63                 annual_inc:100K-120K        0.4668    0.0000
# 64                 annual_inc:120K-140K        0.5570    0.0000
# 65                     annual_inc:>140K        0.4956    0.0000
# 66                            dti:<=1.4        0.2463    0.0034
# 67                          dti:1.4-3.5        0.3694    0.0000
# 68                          dti:3.5-7.7        0.3876    0.0000
# 69                         dti:7.7-10.5        0.3244    0.0000
# 70                        dti:10.5-16.1        0.2466    0.0000
# 71                        dti:16.1-20.3        0.1461    0.0128
# 72                        dti:20.3-21.7        0.1327    0.0305
# 73                        dti:21.7-22.4        0.1021    0.1183
# 74                          dti:22.4-35        0.0573    0.3227
# 75       mths_since_last_delinq:Missing        0.1113    0.0332
# 76          mths_since_last_delinq:4-30        0.1406    0.0077
# 77         mths_since_last_delinq:31-56        0.1863    0.0005
# 78          mths_since_last_delinq:>=57        0.1392    0.0110
# 79       mths_since_last_record:Missing        0.3326    0.0000
# 80          mths_since_last_record:3-20        0.4515    0.0002
# 81         mths_since_last_record:21-31        0.3614    0.0013
# 82         mths_since_last_record:32-80        0.5188    0.0000
# 83         mths_since_last_record:81-86        0.1886    0.0665
# 84           mths_since_last_record:>86        0.2463    0.0036

# %%
import pickle

# %%
pickle.dump(reg2, open('F:\Codes\Dataset\Credit analysis\loan data\pd_model.sav', 'wb'))

# %% [markdown]
# ## PD Model Validation (Test)

# %% [markdown]
# ### Out-of-sample validation

# %%
inputs_test_with_ref_cat = loan_data_inputs_test.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:sm_bus_edu_mov_hou',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:RE_med_wed_vac',
'purpose:home_imp__maj_pur_car',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<95',
'mths_since_issue_d:95-96',
'mths_since_issue_d:97-98',
'mths_since_issue_d:99-105',
'mths_since_issue_d:106-109',
'mths_since_issue_d:110-121',
'mths_since_issue_d:122-141',
'mths_since_issue_d:>141',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>86'
]]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:sm_bus_edu_mov_hou',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>141',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_test = inputs_test_with_ref_cat.drop(ref_categories, axis = 1)
inputs_test.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514        0        0        1        0        0        0
# 288564        0        0        0        0        1        0
# 213591        0        0        1        0        0        0
# 263083        0        0        1        0        0        0
# 165001        1        0        0        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 362514                   0                        1                 0
# 288564                   0                        1                 0
# 213591                   0                        1                 0
# 263083                   0                        1                 0
# 165001                   0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 362514              0  ...                               1
# 288564              0  ...                               0
# 213591              0  ...                               0
# 263083              0  ...                               1
# 165001              0  ...                               0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             0
# 263083                            0                             0
# 165001                            0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:>86
# 362514                           0
# 288564                           0
# 213591                           0
# 263083                           0
# 165001                           0
#
# [5 rows x 84 columns]

# %%
# Assigns each value to either default or not default based on the probability of happening
y_hat_test = reg2.model.predict(inputs_test)

# %%
y_hat_test
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
#Calculates the predicted probability values for the dependent variable of each categories
y_hat_test_proba = reg2.model.predict_proba(inputs_test)

# %%
y_hat_test_proba
# Out:
# array([[0.07540968, 0.92459032],
#        [0.14947547, 0.85052453],
#        [0.11501172, 0.88498828],
#        ...,
#        [0.02702356, 0.97297644],
#        [0.04038632, 0.95961368],
#        [0.04628802, 0.95371198]])

# %%
# we take only the probabilities for being 1
y_hat_test_proba[:][:,1]
# Out:
# array([0.92459032, 0.85052453, 0.88498828, ..., 0.97297644, 0.95961368,
#        0.95371198])

# %%
y_hat_test_proba = y_hat_test_proba[: ][: , 1]

# %%
y_hat_test_proba
# Out:
# array([0.92459032, 0.85052453, 0.88498828, ..., 0.97297644, 0.95961368,
#        0.95371198])

# %%
loan_data_targets_test_temp = loan_data_targets_test

# %%
loan_data_targets_test_temp.reset_index(drop = True, inplace = True)

# %%
df_actual_predicted_probs = pd.concat([loan_data_targets_test_temp, pd.DataFrame(y_hat_test_proba)], axis = 1)

# %%
df_actual_predicted_probs.shape
# Out:
# (93257, 2)

# %%
df_actual_predicted_probs.columns = ['loan_data_targets_test', 'y_hat_test_proba']

# %%
df_actual_predicted_probs.index = loan_data_inputs_test.index

# %%
df_actual_predicted_probs.head()
# Out:
#         loan_data_targets_test  y_hat_test_proba
# 362514                       1            0.9246
# 288564                       1            0.8505
# 213591                       1            0.8850
# 263083                       1            0.9428
# 165001                       1            0.9684

# %% [markdown]
# ### Accuracy and Area under the Curve

# %%
tr = 0.9
df_actual_predicted_probs['y_hat_test'] = np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1, 0)

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], 
            df_actual_predicted_probs['y_hat_test'], 
            rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted      0      1
# Actual
# 0           7367   2823
# 1          35857  47210

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], 
            df_actual_predicted_probs['y_hat_test'],
            rownames = ['Actual'],
            colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]
# Out:
# Predicted      0      1
# Actual
# 0         0.0790 0.0303
# 1         0.3845 0.5062

# %%
# Here we calculate Accuracy of the model, which is the sum of the diagonal rates.
(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'],
             df_actual_predicted_probs['y_hat_test'],
             rownames = ['Actual'], 
             colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[0, 0] +(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'],
                                                                                                       df_actual_predicted_probs['y_hat_test'],
                                                                                                       rownames = ['Actual'], 
                                                                                                       colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[1, 1]
# Out:
# 0.5852322077699261

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %% [markdown]
# We will get Receiver Operating Characteristic (ROC) Curve from a set of actual values and their predicted probabilities.As a result, we get three arrays: the false positive rates, the true positive rates, and the thresholds.

# %%
roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Out:
# (array([0.        , 0.        , 0.        , ..., 0.99950932, 1.        ,
#         1.        ]),
#  array([0.00000000e+00, 1.20384750e-05, 2.52807974e-04, ...,
#         9.99975923e-01, 9.99975923e-01, 1.00000000e+00]),
#  array([1.99266221, 0.99266221, 0.99023263, ..., 0.4842736 , 0.4422138 ,
#         0.36463858]))

# %%
fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %% [markdown]
# Calculating the Area Under the Receiver Operating Characteristic Curve (AUROC) from a set of actual values and their predicted probabilities.

# %% [markdown]
# ![Screenshot%202022-09-05%20153058.png](attachment:Screenshot%202022-09-05%20153058.png)

# %%
AUROC = roc_auc_score(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
AUROC
# Out:
# 0.701702649715596

# %% [markdown]
# ### Gini and Kolmogorov-Smirnov

# %%
df_actual_predicted_probs = df_actual_predicted_probs.sort_values('y_hat_test_proba')

# %%
df_actual_predicted_probs.head()
# Out:
#        loan_data_targets_test  y_hat_test_proba  y_hat_test
# 42341                       1            0.3646           0
# 42344                       1            0.4068           0
# 40518                       0            0.4422           0
# 39810                       0            0.4679           0
# 42396                       0            0.4699           0

# %%
df_actual_predicted_probs = df_actual_predicted_probs.reset_index()

# %%
df_actual_predicted_probs.head()
# Out:
#    index  loan_data_targets_test  y_hat_test_proba  y_hat_test
# 0  42341                       1            0.3646           0
# 1  42344                       1            0.4068           0
# 2  40518                       0            0.4422           0
# 3  39810                       0            0.4679           0
# 4  42396                       0            0.4699           0

# %%
df_actual_predicted_probs['Cumulative N Population'] = df_actual_predicted_probs.index + 1

# %%
df_actual_predicted_probs['Cumulative N Good'] = df_actual_predicted_probs['loan_data_targets_test'].cumsum()

# %%
df_actual_predicted_probs['Cumulative N Bad'] = df_actual_predicted_probs['Cumulative N Population'] - df_actual_predicted_probs['loan_data_targets_test'].cumsum()

# %%
df_actual_predicted_probs.head()
# Out:
#    index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 0  42341                       1            0.3646           0
# 1  42344                       1            0.4068           0
# 2  40518                       0            0.4422           0
# 3  39810                       0            0.4679           0
# 4  42396                       0            0.4699           0
#
#    Cumulative N Population  Cumulative N Good  Cumulative N Bad
# 0                        1                  1                 0
# 1                        2                  2                 0
# 2                        3                  2                 1
# 3                        4                  2                 2
# 4                        5                  2                 3

# %%
df_actual_predicted_probs['Cumulative Perc Population'] = df_actual_predicted_probs['Cumulative N Population'] / (df_actual_predicted_probs.shape[0])

# %%
df_actual_predicted_probs['Cumulative Perc Good'] = df_actual_predicted_probs['Cumulative N Good'] / df_actual_predicted_probs['loan_data_targets_test'].sum()

# %%
df_actual_predicted_probs['Cumulative Perc Bad'] = df_actual_predicted_probs['Cumulative N Bad'] / (df_actual_predicted_probs.shape[0] - df_actual_predicted_probs['loan_data_targets_test'].sum())

# %%
df_actual_predicted_probs.head()
# Out:
#    index  loan_data_targets_test  y_hat_test_proba  y_hat_test  \
# 0  42341                       1            0.3646           0
# 1  42344                       1            0.4068           0
# 2  40518                       0            0.4422           0
# 3  39810                       0            0.4679           0
# 4  42396                       0            0.4699           0
#
#    Cumulative N Population  Cumulative N Good  Cumulative N Bad  \
# 0                        1                  1                 0
# 1                        2                  2                 0
# 2                        3                  2                 1
# 3                        4                  2                 2
# 4                        5                  2                 3
#
#    Cumulative Perc Population  Cumulative Perc Good  Cumulative Perc Bad
# 0                      0.0000                0.0000               0.0000
# 1                      0.0000                0.0000               0.0000
# 2                      0.0000                0.0000               0.0001
# 3                      0.0000                0.0000               0.0002
# 4                      0.0001                0.0000               0.0003

# %% [markdown]
# ## Gini

# %%
plt.plot(df_actual_predicted_probs['Cumulative Perc Population'], df_actual_predicted_probs['Cumulative Perc Bad'])
plt.plot(df_actual_predicted_probs['Cumulative Perc Population'], df_actual_predicted_probs['Cumulative Perc Population'], linestyle = '--', color = 'k')
plt.xlabel('Cumulative % Population')
plt.ylabel('Cumulative % Bad')
plt.title('Gini')
# Out:
# Text(0.5, 1.0, 'Gini')

# %%
Gini = AUROC * 2 -1
Gini
# Out:
# 0.4034052994311921

# %% [markdown]
# ## KS

# %% [markdown]
# ##### Maximum difference between the cummulative difference between the cummulative distributions functions of 'good' and 'bad' borrowers. Value ranges between 0 an 1. Higher the value, higher the model is fitted

# %%
plt.plot(df_actual_predicted_probs['y_hat_test_proba'], df_actual_predicted_probs['Cumulative Perc Bad'], color = 'r')
plt.plot(df_actual_predicted_probs['y_hat_test_proba'], df_actual_predicted_probs['Cumulative Perc Good'], color = 'b')
plt.xlabel('Estimated Probability for being Good')
plt.ylabel('Cumulative %')
plt.title('Kolmogorov-Smirnov')
# Out:
# Text(0.5, 1.0, 'Kolmogorov-Smirnov')

# %% [markdown]
# ## Applying the PD Model

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 362514        0        0        1        0        0        0        0
# 288564        0        0        0        0        1        0        0
# 213591        0        0        1        0        0        0        0
# 263083        0        0        1        0        0        0        0
# 165001        1        0        0        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514                                   0                   0
# 288564                                   0                   0
# 213591                                   0                   0
# 263083                                   0                   0
# 165001                                   0                   0
#
#         home_ownership:MORTGAGE  ...  mths_since_last_delinq:4-30  \
# 362514                        1  ...                            0
# 288564                        1  ...                            0
# 213591                        1  ...                            0
# 263083                        1  ...                            0
# 165001                        1  ...                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 362514                             0                            0
# 288564                             0                            0
# 213591                             1                            0
# 263083                             0                            0
# 165001                             1                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:0-2  \
# 362514                               1                           0
# 288564                               1                           0
# 213591                               1                           0
# 263083                               1                           0
# 165001                               1                           0
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             0
# 263083                            0                             0
# 165001                            0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:>86
# 362514                           0
# 288564                           0
# 213591                           0
# 263083                           0
# 165001                           0
#
# [5 rows x 101 columns]

# %%
summary_table
# Out:
#                            Feature name  Coefficients  p_values
# 0                             Intercept       -1.4247       NaN
# 1                               grade:A        1.1410    0.0000
# 2                               grade:B        0.8952    0.0000
# 3                               grade:C        0.6996    0.0000
# 4                               grade:D        0.5104    0.0000
# 5                               grade:E        0.3328    0.0000
# 6                               grade:F        0.1442    0.0034
# 7                    home_ownership:OWN        0.0979    0.0000
# 8               home_ownership:MORTGAGE        0.1093    0.0000
# 9                      addr_state:NM_VA        0.0369    0.2489
# 10                        addr_state:NY        0.0563    0.0201
# 11         addr_state:OK_TN_MO_LA_MD_NC        0.0569    0.0140
# 12                        addr_state:CA        0.0620    0.0035
# 13               addr_state:UT_KY_AZ_NJ        0.0760    0.0023
# 14            addr_state:AR_MI_PA_OH_MN        0.1332    0.0000
# 15            addr_state:RI_MA_DE_SD_IN        0.0980    0.0010
# 16                  addr_state:GA_WA_OR        0.1836    0.0000
# 17                     addr_state:WI_MT        0.2343    0.0000
# 18                        addr_state:TX        0.2203    0.0000
# 19                     addr_state:IL_CT        0.2597    0.0000
# 20         addr_state:KS_SC_CO_VT_AK_MS        0.3194    0.0000
# 21         addr_state:WV_NH_WY_DC_ME_ID        0.5177    0.0000
# 22     verification_status:Not Verified        0.0870    0.0000
# 23  verification_status:Source Verified       -0.0116    0.3871
# 24                  purpose:credit_card        0.2020    0.0000
# 25           purpose:debt_consolidation        0.0986    0.0000
# 26               purpose:RE_med_wed_vac        0.2009    0.0000
# 27        purpose:home_imp__maj_pur_car        0.1663    0.0000
# 28                initial_list_status:w        0.0542    0.0000
# 29                              term:36        0.0773    0.0000
# 30                         emp_length:1        0.0956    0.0002
# 31                       emp_length:2-4        0.1215    0.0000
# 32                       emp_length:5-6        0.0874    0.0000
# 33                       emp_length:7-9        0.0586    0.0049
# 34                        emp_length:10        0.1268    0.0000
# 35               mths_since_issue_d:<95        1.0871    0.0000
# 36             mths_since_issue_d:95-96        0.8822    0.0000
# 37             mths_since_issue_d:97-98        0.7806    0.0000
# 38            mths_since_issue_d:99-105        0.5787    0.0000
# 39           mths_since_issue_d:106-109        0.4171    0.0000
# 40           mths_since_issue_d:110-121        0.1678    0.0000
# 41           mths_since_issue_d:122-141       -0.0780    0.0077
# 42                      int_rate:<9.548        0.8774    0.0000
# 43                int_rate:9.548-12.025        0.5528    0.0000
# 44                int_rate:12.025-15.74        0.3012    0.0000
# 45                int_rate:15.74-20.281        0.1104    0.0001
# 46  mths_since_earliest_cr_line:141-164        0.0729    0.3726
# 47  mths_since_earliest_cr_line:165-247        0.1426    0.0429
# 48  mths_since_earliest_cr_line:248-270        0.1368    0.0548
# 49  mths_since_earliest_cr_line:271-352        0.1750    0.0131
# 50     mths_since_earliest_cr_line:>352        0.2215    0.0018
# 51                     inq_last_6mths:0        0.6819    0.0000
# 52                   inq_last_6mths:1-2        0.5345    0.0000
# 53                   inq_last_6mths:3-6        0.3235    0.0006
# 54                   acc_now_delinq:>=1        0.1826    0.0845
# 55                   annual_inc:20K-30K       -0.0783    0.0635
# 56                   annual_inc:30K-40K       -0.0171    0.6730
# 57                   annual_inc:40K-50K        0.0771    0.0567
# 58                   annual_inc:50K-60K        0.1436    0.0005
# 59                   annual_inc:60K-70K        0.2193    0.0000
# 60                   annual_inc:70K-80K        0.2927    0.0000
# 61                   annual_inc:80K-90K        0.3706    0.0000
# 62                  annual_inc:90K-100K        0.3892    0.0000
# 63                 annual_inc:100K-120K        0.4668    0.0000
# 64                 annual_inc:120K-140K        0.5570    0.0000
# 65                     annual_inc:>140K        0.4956    0.0000
# 66                            dti:<=1.4        0.2463    0.0034
# 67                          dti:1.4-3.5        0.3694    0.0000
# 68                          dti:3.5-7.7        0.3876    0.0000
# 69                         dti:7.7-10.5        0.3244    0.0000
# 70                        dti:10.5-16.1        0.2466    0.0000
# 71                        dti:16.1-20.3        0.1461    0.0128
# 72                        dti:20.3-21.7        0.1327    0.0305
# 73                        dti:21.7-22.4        0.1021    0.1183
# 74                          dti:22.4-35        0.0573    0.3227
# 75       mths_since_last_delinq:Missing        0.1113    0.0332
# 76          mths_since_last_delinq:4-30        0.1406    0.0077
# 77         mths_since_last_delinq:31-56        0.1863    0.0005
# 78          mths_since_last_delinq:>=57        0.1392    0.0110
# 79       mths_since_last_record:Missing        0.3326    0.0000
# 80          mths_since_last_record:3-20        0.4515    0.0002
# 81         mths_since_last_record:21-31        0.3614    0.0013
# 82         mths_since_last_record:32-80        0.5188    0.0000
# 83         mths_since_last_record:81-86        0.1886    0.0665
# 84           mths_since_last_record:>86        0.2463    0.0036

# %%
y_hat_test_proba
# Out:
# array([0.92459032, 0.85052453, 0.88498828, ..., 0.97297644, 0.95961368,
#        0.95371198])

# %% [markdown]
# ## Creating a Scorecard

# %%
ref_categories
# Out:
# ['grade:G',
#  'home_ownership:RENT_OTHER_NONE_ANY',
#  'addr_state:ND_NE_IA_NV_FL_HI_AL',
#  'verification_status:Verified',
#  'purpose:sm_bus_edu_mov_hou',
#  'initial_list_status:f',
#  'term:60',
#  'emp_length:0',
#  'mths_since_issue_d:>141',
#  'int_rate:>20.281',
#  'mths_since_earliest_cr_line:<140',
#  'inq_last_6mths:>6',
#  'acc_now_delinq:0',
#  'annual_inc:<20K',
#  'dti:>35',
#  'mths_since_last_delinq:0-3',
#  'mths_since_last_record:0-2']

# %%
df_ref_categories = pd.DataFrame(ref_categories, columns = ['Feature name'])

# %%
df_ref_categories['Coefficients'] = 0

# %%
df_ref_categories['p_values'] = np.nan

# %%
df_ref_categories
# Out:
#                           Feature name  Coefficients  p_values
# 0                              grade:G             0       NaN
# 1   home_ownership:RENT_OTHER_NONE_ANY             0       NaN
# 2      addr_state:ND_NE_IA_NV_FL_HI_AL             0       NaN
# 3         verification_status:Verified             0       NaN
# 4           purpose:sm_bus_edu_mov_hou             0       NaN
# 5                initial_list_status:f             0       NaN
# 6                              term:60             0       NaN
# 7                         emp_length:0             0       NaN
# 8              mths_since_issue_d:>141             0       NaN
# 9                     int_rate:>20.281             0       NaN
# 10    mths_since_earliest_cr_line:<140             0       NaN
# 11                   inq_last_6mths:>6             0       NaN
# 12                    acc_now_delinq:0             0       NaN
# 13                     annual_inc:<20K             0       NaN
# 14                             dti:>35             0       NaN
# 15          mths_since_last_delinq:0-3             0       NaN
# 16          mths_since_last_record:0-2             0       NaN

# %%
df_scorecard = pd.concat([summary_table, df_ref_categories])

# %%
df_scorecard.reset_index(drop = True, inplace = True)

# %%
df_scorecard['Original feature name'] = df_scorecard['Feature name'].str.split(':').str[0]
df_scorecard
# Out:
#                             Feature name  Coefficients  p_values  \
# 0                              Intercept       -1.4247       NaN
# 1                                grade:A        1.1410    0.0000
# 2                                grade:B        0.8952    0.0000
# 3                                grade:C        0.6996    0.0000
# 4                                grade:D        0.5104    0.0000
# 5                                grade:E        0.3328    0.0000
# 6                                grade:F        0.1442    0.0034
# 7                     home_ownership:OWN        0.0979    0.0000
# 8                home_ownership:MORTGAGE        0.1093    0.0000
# 9                       addr_state:NM_VA        0.0369    0.2489
# 10                         addr_state:NY        0.0563    0.0201
# 11          addr_state:OK_TN_MO_LA_MD_NC        0.0569    0.0140
# 12                         addr_state:CA        0.0620    0.0035
# 13                addr_state:UT_KY_AZ_NJ        0.0760    0.0023
# 14             addr_state:AR_MI_PA_OH_MN        0.1332    0.0000
# 15             addr_state:RI_MA_DE_SD_IN        0.0980    0.0010
# 16                   addr_state:GA_WA_OR        0.1836    0.0000
# 17                      addr_state:WI_MT        0.2343    0.0000
# 18                         addr_state:TX        0.2203    0.0000
# 19                      addr_state:IL_CT        0.2597    0.0000
# 20          addr_state:KS_SC_CO_VT_AK_MS        0.3194    0.0000
# 21          addr_state:WV_NH_WY_DC_ME_ID        0.5177    0.0000
# 22      verification_status:Not Verified        0.0870    0.0000
# 23   verification_status:Source Verified       -0.0116    0.3871
# 24                   purpose:credit_card        0.2020    0.0000
# 25            purpose:debt_consolidation        0.0986    0.0000
# 26                purpose:RE_med_wed_vac        0.2009    0.0000
# 27         purpose:home_imp__maj_pur_car        0.1663    0.0000
# 28                 initial_list_status:w        0.0542    0.0000
# 29                               term:36        0.0773    0.0000
# 30                          emp_length:1        0.0956    0.0002
# 31                        emp_length:2-4        0.1215    0.0000
# 32                        emp_length:5-6        0.0874    0.0000
# 33                        emp_length:7-9        0.0586    0.0049
# 34                         emp_length:10        0.1268    0.0000
# 35                mths_since_issue_d:<95        1.0871    0.0000
# 36              mths_since_issue_d:95-96        0.8822    0.0000
# 37              mths_since_issue_d:97-98        0.7806    0.0000
# 38             mths_since_issue_d:99-105        0.5787    0.0000
# 39            mths_since_issue_d:106-109        0.4171    0.0000
# 40            mths_since_issue_d:110-121        0.1678    0.0000
# 41            mths_since_issue_d:122-141       -0.0780    0.0077
# 42                       int_rate:<9.548        0.8774    0.0000
# 43                 int_rate:9.548-12.025        0.5528    0.0000
# 44                 int_rate:12.025-15.74        0.3012    0.0000
# 45                 int_rate:15.74-20.281        0.1104    0.0001
# 46   mths_since_earliest_cr_line:141-164        0.0729    0.3726
# 47   mths_since_earliest_cr_line:165-247        0.1426    0.0429
# 48   mths_since_earliest_cr_line:248-270        0.1368    0.0548
# 49   mths_since_earliest_cr_line:271-352        0.1750    0.0131
# 50      mths_since_earliest_cr_line:>352        0.2215    0.0018
# 51                      inq_last_6mths:0        0.6819    0.0000
# 52                    inq_last_6mths:1-2        0.5345    0.0000
# 53                    inq_last_6mths:3-6        0.3235    0.0006
# 54                    acc_now_delinq:>=1        0.1826    0.0845
# 55                    annual_inc:20K-30K       -0.0783    0.0635
# 56                    annual_inc:30K-40K       -0.0171    0.6730
# 57                    annual_inc:40K-50K        0.0771    0.0567
# 58                    annual_inc:50K-60K        0.1436    0.0005
# 59                    annual_inc:60K-70K        0.2193    0.0000
# 60                    annual_inc:70K-80K        0.2927    0.0000
# 61                    annual_inc:80K-90K        0.3706    0.0000
# 62                   annual_inc:90K-100K        0.3892    0.0000
# 63                  annual_inc:100K-120K        0.4668    0.0000
# 64                  annual_inc:120K-140K        0.5570    0.0000
# 65                      annual_inc:>140K        0.4956    0.0000
# 66                             dti:<=1.4        0.2463    0.0034
# 67                           dti:1.4-3.5        0.3694    0.0000
# 68                           dti:3.5-7.7        0.3876    0.0000
# 69                          dti:7.7-10.5        0.3244    0.0000
# 70                         dti:10.5-16.1        0.2466    0.0000
# 71                         dti:16.1-20.3        0.1461    0.0128
# 72                         dti:20.3-21.7        0.1327    0.0305
# 73                         dti:21.7-22.4        0.1021    0.1183
# 74                           dti:22.4-35        0.0573    0.3227
# 75        mths_since_last_delinq:Missing        0.1113    0.0332
# 76           mths_since_last_delinq:4-30        0.1406    0.0077
# 77          mths_since_last_delinq:31-56        0.1863    0.0005
# 78           mths_since_last_delinq:>=57        0.1392    0.0110
# 79        mths_since_last_record:Missing        0.3326    0.0000
# 80           mths_since_last_record:3-20        0.4515    0.0002
# 81          mths_since_last_record:21-31        0.3614    0.0013
# 82          mths_since_last_record:32-80        0.5188    0.0000
# 83          mths_since_last_record:81-86        0.1886    0.0665
# 84            mths_since_last_record:>86        0.2463    0.0036
# 85                               grade:G        0.0000       NaN
# 86    home_ownership:RENT_OTHER_NONE_ANY        0.0000       NaN
# 87       addr_state:ND_NE_IA_NV_FL_HI_AL        0.0000       NaN
# 88          verification_status:Verified        0.0000       NaN
# 89            purpose:sm_bus_edu_mov_hou        0.0000       NaN
# 90                 initial_list_status:f        0.0000       NaN
# 91                               term:60        0.0000       NaN
# 92                          emp_length:0        0.0000       NaN
# 93               mths_since_issue_d:>141        0.0000       NaN
# 94                      int_rate:>20.281        0.0000       NaN
# 95      mths_since_earliest_cr_line:<140        0.0000       NaN
# 96                     inq_last_6mths:>6        0.0000       NaN
# 97                      acc_now_delinq:0        0.0000       NaN
# 98                       annual_inc:<20K        0.0000       NaN
# 99                               dti:>35        0.0000       NaN
# 100           mths_since_last_delinq:0-3        0.0000       NaN
# 101           mths_since_last_record:0-2        0.0000       NaN
#
#            Original feature name
# 0                      Intercept
# 1                          grade
# 2                          grade
# 3                          grade
# 4                          grade
# 5                          grade
# 6                          grade
# 7                 home_ownership
# 8                 home_ownership
# 9                     addr_state
# 10                    addr_state
# 11                    addr_state
# 12                    addr_state
# 13                    addr_state
# 14                    addr_state
# 15                    addr_state
# 16                    addr_state
# 17                    addr_state
# 18                    addr_state
# 19                    addr_state
# 20                    addr_state
# 21                    addr_state
# 22           verification_status
# 23           verification_status
# 24                       purpose
# 25                       purpose
# 26                       purpose
# 27                       purpose
# 28           initial_list_status
# 29                          term
# 30                    emp_length
# 31                    emp_length
# 32                    emp_length
# 33                    emp_length
# 34                    emp_length
# 35            mths_since_issue_d
# 36            mths_since_issue_d
# 37            mths_since_issue_d
# 38            mths_since_issue_d
# 39            mths_since_issue_d
# 40            mths_since_issue_d
# 41            mths_since_issue_d
# 42                      int_rate
# 43                      int_rate
# 44                      int_rate
# 45                      int_rate
# 46   mths_since_earliest_cr_line
# 47   mths_since_earliest_cr_line
# 48   mths_since_earliest_cr_line
# 49   mths_since_earliest_cr_line
# 50   mths_since_earliest_cr_line
# 51                inq_last_6mths
# 52                inq_last_6mths
# 53                inq_last_6mths
# 54                acc_now_delinq
# 55                    annual_inc
# 56                    annual_inc
# 57                    annual_inc
# 58                    annual_inc
# 59                    annual_inc
# 60                    annual_inc
# 61                    annual_inc
# 62                    annual_inc
# 63                    annual_inc
# 64                    annual_inc
# 65                    annual_inc
# 66                           dti
# 67                           dti
# 68                           dti
# 69                           dti
# 70                           dti
# 71                           dti
# 72                           dti
# 73                           dti
# 74                           dti
# 75        mths_since_last_delinq
# 76        mths_since_last_delinq
# 77        mths_since_last_delinq
# 78        mths_since_last_delinq
# 79        mths_since_last_record
# 80        mths_since_last_record
# 81        mths_since_last_record
# 82        mths_since_last_record
# 83        mths_since_last_record
# 84        mths_since_last_record
# 85                         grade
# 86                home_ownership
# 87                    addr_state
# 88           verification_status
# 89                       purpose
# 90           initial_list_status
# 91                          term
# 92                    emp_length
# 93            mths_since_issue_d
# 94                      int_rate
# 95   mths_since_earliest_cr_line
# 96                inq_last_6mths
# 97                acc_now_delinq
# 98                    annual_inc
# 99                           dti
# 100       mths_since_last_delinq
# 101       mths_since_last_record

# %%
min_score = 300
max_score = 850

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].min()
# Out:
# Original feature name
# Intercept                     -1.4247
# acc_now_delinq                 0.0000
# addr_state                     0.0000
# annual_inc                    -0.0783
# dti                            0.0000
# emp_length                     0.0000
# grade                          0.0000
# home_ownership                 0.0000
# initial_list_status            0.0000
# inq_last_6mths                 0.0000
# int_rate                       0.0000
# mths_since_earliest_cr_line    0.0000
# mths_since_issue_d            -0.0780
# mths_since_last_delinq         0.0000
# mths_since_last_record         0.0000
# purpose                        0.0000
# term                           0.0000
# verification_status           -0.0116
# Name: Coefficients, dtype: float64

# %%
min_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].min().sum()
min_sum_coef
# Out:
# -1.5925972834670146

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].max()
# Out:
# Original feature name
# Intercept                     -1.4247
# acc_now_delinq                 0.1826
# addr_state                     0.5177
# annual_inc                     0.5570
# dti                            0.3876
# emp_length                     0.1268
# grade                          1.1410
# home_ownership                 0.1093
# initial_list_status            0.0542
# inq_last_6mths                 0.6819
# int_rate                       0.8774
# mths_since_earliest_cr_line    0.2215
# mths_since_issue_d             1.0871
# mths_since_last_delinq         0.1863
# mths_since_last_record         0.5188
# purpose                        0.2020
# term                           0.0773
# verification_status            0.0870
# Name: Coefficients, dtype: float64

# %%
max_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].max().sum()
max_sum_coef
# Out:
# 5.590870310483823

# %%
df_scorecard['Score - Calculation'] = df_scorecard['Coefficients'] * (max_score - min_score) / (max_sum_coef - min_sum_coef)
df_scorecard
# Out:
#                             Feature name  Coefficients  p_values  \
# 0                              Intercept       -1.4247       NaN
# 1                                grade:A        1.1410    0.0000
# 2                                grade:B        0.8952    0.0000
# 3                                grade:C        0.6996    0.0000
# 4                                grade:D        0.5104    0.0000
# 5                                grade:E        0.3328    0.0000
# 6                                grade:F        0.1442    0.0034
# 7                     home_ownership:OWN        0.0979    0.0000
# 8                home_ownership:MORTGAGE        0.1093    0.0000
# 9                       addr_state:NM_VA        0.0369    0.2489
# 10                         addr_state:NY        0.0563    0.0201
# 11          addr_state:OK_TN_MO_LA_MD_NC        0.0569    0.0140
# 12                         addr_state:CA        0.0620    0.0035
# 13                addr_state:UT_KY_AZ_NJ        0.0760    0.0023
# 14             addr_state:AR_MI_PA_OH_MN        0.1332    0.0000
# 15             addr_state:RI_MA_DE_SD_IN        0.0980    0.0010
# 16                   addr_state:GA_WA_OR        0.1836    0.0000
# 17                      addr_state:WI_MT        0.2343    0.0000
# 18                         addr_state:TX        0.2203    0.0000
# 19                      addr_state:IL_CT        0.2597    0.0000
# 20          addr_state:KS_SC_CO_VT_AK_MS        0.3194    0.0000
# 21          addr_state:WV_NH_WY_DC_ME_ID        0.5177    0.0000
# 22      verification_status:Not Verified        0.0870    0.0000
# 23   verification_status:Source Verified       -0.0116    0.3871
# 24                   purpose:credit_card        0.2020    0.0000
# 25            purpose:debt_consolidation        0.0986    0.0000
# 26                purpose:RE_med_wed_vac        0.2009    0.0000
# 27         purpose:home_imp__maj_pur_car        0.1663    0.0000
# 28                 initial_list_status:w        0.0542    0.0000
# 29                               term:36        0.0773    0.0000
# 30                          emp_length:1        0.0956    0.0002
# 31                        emp_length:2-4        0.1215    0.0000
# 32                        emp_length:5-6        0.0874    0.0000
# 33                        emp_length:7-9        0.0586    0.0049
# 34                         emp_length:10        0.1268    0.0000
# 35                mths_since_issue_d:<95        1.0871    0.0000
# 36              mths_since_issue_d:95-96        0.8822    0.0000
# 37              mths_since_issue_d:97-98        0.7806    0.0000
# 38             mths_since_issue_d:99-105        0.5787    0.0000
# 39            mths_since_issue_d:106-109        0.4171    0.0000
# 40            mths_since_issue_d:110-121        0.1678    0.0000
# 41            mths_since_issue_d:122-141       -0.0780    0.0077
# 42                       int_rate:<9.548        0.8774    0.0000
# 43                 int_rate:9.548-12.025        0.5528    0.0000
# 44                 int_rate:12.025-15.74        0.3012    0.0000
# 45                 int_rate:15.74-20.281        0.1104    0.0001
# 46   mths_since_earliest_cr_line:141-164        0.0729    0.3726
# 47   mths_since_earliest_cr_line:165-247        0.1426    0.0429
# 48   mths_since_earliest_cr_line:248-270        0.1368    0.0548
# 49   mths_since_earliest_cr_line:271-352        0.1750    0.0131
# 50      mths_since_earliest_cr_line:>352        0.2215    0.0018
# 51                      inq_last_6mths:0        0.6819    0.0000
# 52                    inq_last_6mths:1-2        0.5345    0.0000
# 53                    inq_last_6mths:3-6        0.3235    0.0006
# 54                    acc_now_delinq:>=1        0.1826    0.0845
# 55                    annual_inc:20K-30K       -0.0783    0.0635
# 56                    annual_inc:30K-40K       -0.0171    0.6730
# 57                    annual_inc:40K-50K        0.0771    0.0567
# 58                    annual_inc:50K-60K        0.1436    0.0005
# 59                    annual_inc:60K-70K        0.2193    0.0000
# 60                    annual_inc:70K-80K        0.2927    0.0000
# 61                    annual_inc:80K-90K        0.3706    0.0000
# 62                   annual_inc:90K-100K        0.3892    0.0000
# 63                  annual_inc:100K-120K        0.4668    0.0000
# 64                  annual_inc:120K-140K        0.5570    0.0000
# 65                      annual_inc:>140K        0.4956    0.0000
# 66                             dti:<=1.4        0.2463    0.0034
# 67                           dti:1.4-3.5        0.3694    0.0000
# 68                           dti:3.5-7.7        0.3876    0.0000
# 69                          dti:7.7-10.5        0.3244    0.0000
# 70                         dti:10.5-16.1        0.2466    0.0000
# 71                         dti:16.1-20.3        0.1461    0.0128
# 72                         dti:20.3-21.7        0.1327    0.0305
# 73                         dti:21.7-22.4        0.1021    0.1183
# 74                           dti:22.4-35        0.0573    0.3227
# 75        mths_since_last_delinq:Missing        0.1113    0.0332
# 76           mths_since_last_delinq:4-30        0.1406    0.0077
# 77          mths_since_last_delinq:31-56        0.1863    0.0005
# 78           mths_since_last_delinq:>=57        0.1392    0.0110
# 79        mths_since_last_record:Missing        0.3326    0.0000
# 80           mths_since_last_record:3-20        0.4515    0.0002
# 81          mths_since_last_record:21-31        0.3614    0.0013
# 82          mths_since_last_record:32-80        0.5188    0.0000
# 83          mths_since_last_record:81-86        0.1886    0.0665
# 84            mths_since_last_record:>86        0.2463    0.0036
# 85                               grade:G        0.0000       NaN
# 86    home_ownership:RENT_OTHER_NONE_ANY        0.0000       NaN
# 87       addr_state:ND_NE_IA_NV_FL_HI_AL        0.0000       NaN
# 88          verification_status:Verified        0.0000       NaN
# 89            purpose:sm_bus_edu_mov_hou        0.0000       NaN
# 90                 initial_list_status:f        0.0000       NaN
# 91                               term:60        0.0000       NaN
# 92                          emp_length:0        0.0000       NaN
# 93               mths_since_issue_d:>141        0.0000       NaN
# 94                      int_rate:>20.281        0.0000       NaN
# 95      mths_since_earliest_cr_line:<140        0.0000       NaN
# 96                     inq_last_6mths:>6        0.0000       NaN
# 97                      acc_now_delinq:0        0.0000       NaN
# 98                       annual_inc:<20K        0.0000       NaN
# 99                               dti:>35        0.0000       NaN
# 100           mths_since_last_delinq:0-3        0.0000       NaN
# 101           mths_since_last_record:0-2        0.0000       NaN
#
#            Original feature name  Score - Calculation
# 0                      Intercept            -109.0795
# 1                          grade              87.3580
# 2                          grade              68.5438
# 3                          grade              53.5661
# 4                          grade              39.0799
# 5                          grade              25.4791
# 6                          grade              11.0368
# 7                 home_ownership               7.4985
# 8                 home_ownership               8.3681
# 9                     addr_state               2.8289
# 10                    addr_state               4.3119
# 11                    addr_state               4.3595
# 12                    addr_state               4.7475
# 13                    addr_state               5.8156
# 14                    addr_state              10.1957
# 15                    addr_state               7.5013
# 16                    addr_state              14.0582
# 17                    addr_state              17.9358
# 18                    addr_state              16.8653
# 19                    addr_state              19.8836
# 20                    addr_state              24.4509
# 21                    addr_state              39.6379
# 22           verification_status               6.6583
# 23           verification_status              -0.8895
# 24                       purpose              15.4661
# 25                       purpose               7.5490
# 26                       purpose              15.3827
# 27                       purpose              12.7293
# 28           initial_list_status               4.1526
# 29                          term               5.9206
# 30                    emp_length               7.3169
# 31                    emp_length               9.3048
# 32                    emp_length               6.6890
# 33                    emp_length               4.4859
# 34                    emp_length               9.7087
# 35            mths_since_issue_d              83.2364
# 36            mths_since_issue_d              67.5486
# 37            mths_since_issue_d              59.7631
# 38            mths_since_issue_d              44.3063
# 39            mths_since_issue_d              31.9344
# 40            mths_since_issue_d              12.8468
# 41            mths_since_issue_d              -5.9688
# 42                      int_rate              67.1763
# 43                      int_rate              42.3274
# 44                      int_rate              23.0607
# 45                      int_rate               8.4521
# 46   mths_since_earliest_cr_line               5.5786
# 47   mths_since_earliest_cr_line              10.9206
# 48   mths_since_earliest_cr_line              10.4769
# 49   mths_since_earliest_cr_line              13.3965
# 50   mths_since_earliest_cr_line              16.9587
# 51                inq_last_6mths              52.2116
# 52                inq_last_6mths              40.9230
# 53                inq_last_6mths              24.7666
# 54                acc_now_delinq              13.9829
# 55                    annual_inc              -5.9988
# 56                    annual_inc              -1.3102
# 57                    annual_inc               5.9031
# 58                    annual_inc              10.9909
# 59                    annual_inc              16.7904
# 60                    annual_inc              22.4092
# 61                    annual_inc              28.3779
# 62                    annual_inc              29.7999
# 63                    annual_inc              35.7394
# 64                    annual_inc              42.6485
# 65                    annual_inc              37.9462
# 66                           dti              18.8557
# 67                           dti              28.2799
# 68                           dti              29.6755
# 69                           dti              24.8347
# 70                           dti              18.8800
# 71                           dti              11.1866
# 72                           dti              10.1593
# 73                           dti               7.8195
# 74                           dti               4.3905
# 75        mths_since_last_delinq               8.5244
# 76        mths_since_last_delinq              10.7647
# 77        mths_since_last_delinq              14.2603
# 78        mths_since_last_delinq              10.6584
# 79        mths_since_last_record              25.4660
# 80        mths_since_last_record              34.5696
# 81        mths_since_last_record              27.6724
# 82        mths_since_last_record              39.7222
# 83        mths_since_last_record              14.4365
# 84        mths_since_last_record              18.8571
# 85                         grade               0.0000
# 86                home_ownership               0.0000
# 87                    addr_state               0.0000
# 88           verification_status               0.0000
# 89                       purpose               0.0000
# 90           initial_list_status               0.0000
# 91                          term               0.0000
# 92                    emp_length               0.0000
# 93            mths_since_issue_d               0.0000
# 94                      int_rate               0.0000
# 95   mths_since_earliest_cr_line               0.0000
# 96                inq_last_6mths               0.0000
# 97                acc_now_delinq               0.0000
# 98                    annual_inc               0.0000
# 99                           dti               0.0000
# 100       mths_since_last_delinq               0.0000
# 101       mths_since_last_record               0.0000

# %%
df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
df_scorecard
# Out:
# C:\Users\sathi\AppData\Local\Temp/ipykernel_13144/1263832758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
#                             Feature name  Coefficients  p_values  \
# 0                              Intercept       -1.4247       NaN
# 1                                grade:A        1.1410    0.0000
# 2                                grade:B        0.8952    0.0000
# 3                                grade:C        0.6996    0.0000
# 4                                grade:D        0.5104    0.0000
# 5                                grade:E        0.3328    0.0000
# 6                                grade:F        0.1442    0.0034
# 7                     home_ownership:OWN        0.0979    0.0000
# 8                home_ownership:MORTGAGE        0.1093    0.0000
# 9                       addr_state:NM_VA        0.0369    0.2489
# 10                         addr_state:NY        0.0563    0.0201
# 11          addr_state:OK_TN_MO_LA_MD_NC        0.0569    0.0140
# 12                         addr_state:CA        0.0620    0.0035
# 13                addr_state:UT_KY_AZ_NJ        0.0760    0.0023
# 14             addr_state:AR_MI_PA_OH_MN        0.1332    0.0000
# 15             addr_state:RI_MA_DE_SD_IN        0.0980    0.0010
# 16                   addr_state:GA_WA_OR        0.1836    0.0000
# 17                      addr_state:WI_MT        0.2343    0.0000
# 18                         addr_state:TX        0.2203    0.0000
# 19                      addr_state:IL_CT        0.2597    0.0000
# 20          addr_state:KS_SC_CO_VT_AK_MS        0.3194    0.0000
# 21          addr_state:WV_NH_WY_DC_ME_ID        0.5177    0.0000
# 22      verification_status:Not Verified        0.0870    0.0000
# 23   verification_status:Source Verified       -0.0116    0.3871
# 24                   purpose:credit_card        0.2020    0.0000
# 25            purpose:debt_consolidation        0.0986    0.0000
# 26                purpose:RE_med_wed_vac        0.2009    0.0000
# 27         purpose:home_imp__maj_pur_car        0.1663    0.0000
# 28                 initial_list_status:w        0.0542    0.0000
# 29                               term:36        0.0773    0.0000
# 30                          emp_length:1        0.0956    0.0002
# 31                        emp_length:2-4        0.1215    0.0000
# 32                        emp_length:5-6        0.0874    0.0000
# 33                        emp_length:7-9        0.0586    0.0049
# 34                         emp_length:10        0.1268    0.0000
# 35                mths_since_issue_d:<95        1.0871    0.0000
# 36              mths_since_issue_d:95-96        0.8822    0.0000
# 37              mths_since_issue_d:97-98        0.7806    0.0000
# 38             mths_since_issue_d:99-105        0.5787    0.0000
# 39            mths_since_issue_d:106-109        0.4171    0.0000
# 40            mths_since_issue_d:110-121        0.1678    0.0000
# 41            mths_since_issue_d:122-141       -0.0780    0.0077
# 42                       int_rate:<9.548        0.8774    0.0000
# 43                 int_rate:9.548-12.025        0.5528    0.0000
# 44                 int_rate:12.025-15.74        0.3012    0.0000
# 45                 int_rate:15.74-20.281        0.1104    0.0001
# 46   mths_since_earliest_cr_line:141-164        0.0729    0.3726
# 47   mths_since_earliest_cr_line:165-247        0.1426    0.0429
# 48   mths_since_earliest_cr_line:248-270        0.1368    0.0548
# 49   mths_since_earliest_cr_line:271-352        0.1750    0.0131
# 50      mths_since_earliest_cr_line:>352        0.2215    0.0018
# 51                      inq_last_6mths:0        0.6819    0.0000
# 52                    inq_last_6mths:1-2        0.5345    0.0000
# 53                    inq_last_6mths:3-6        0.3235    0.0006
# 54                    acc_now_delinq:>=1        0.1826    0.0845
# 55                    annual_inc:20K-30K       -0.0783    0.0635
# 56                    annual_inc:30K-40K       -0.0171    0.6730
# 57                    annual_inc:40K-50K        0.0771    0.0567
# 58                    annual_inc:50K-60K        0.1436    0.0005
# 59                    annual_inc:60K-70K        0.2193    0.0000
# 60                    annual_inc:70K-80K        0.2927    0.0000
# 61                    annual_inc:80K-90K        0.3706    0.0000
# 62                   annual_inc:90K-100K        0.3892    0.0000
# 63                  annual_inc:100K-120K        0.4668    0.0000
# 64                  annual_inc:120K-140K        0.5570    0.0000
# 65                      annual_inc:>140K        0.4956    0.0000
# 66                             dti:<=1.4        0.2463    0.0034
# 67                           dti:1.4-3.5        0.3694    0.0000
# 68                           dti:3.5-7.7        0.3876    0.0000
# 69                          dti:7.7-10.5        0.3244    0.0000
# 70                         dti:10.5-16.1        0.2466    0.0000
# 71                         dti:16.1-20.3        0.1461    0.0128
# 72                         dti:20.3-21.7        0.1327    0.0305
# 73                         dti:21.7-22.4        0.1021    0.1183
# 74                           dti:22.4-35        0.0573    0.3227
# 75        mths_since_last_delinq:Missing        0.1113    0.0332
# 76           mths_since_last_delinq:4-30        0.1406    0.0077
# 77          mths_since_last_delinq:31-56        0.1863    0.0005
# 78           mths_since_last_delinq:>=57        0.1392    0.0110
# 79        mths_since_last_record:Missing        0.3326    0.0000
# 80           mths_since_last_record:3-20        0.4515    0.0002
# 81          mths_since_last_record:21-31        0.3614    0.0013
# 82          mths_since_last_record:32-80        0.5188    0.0000
# 83          mths_since_last_record:81-86        0.1886    0.0665
# 84            mths_since_last_record:>86        0.2463    0.0036
# 85                               grade:G        0.0000       NaN
# 86    home_ownership:RENT_OTHER_NONE_ANY        0.0000       NaN
# 87       addr_state:ND_NE_IA_NV_FL_HI_AL        0.0000       NaN
# 88          verification_status:Verified        0.0000       NaN
# 89            purpose:sm_bus_edu_mov_hou        0.0000       NaN
# 90                 initial_list_status:f        0.0000       NaN
# 91                               term:60        0.0000       NaN
# 92                          emp_length:0        0.0000       NaN
# 93               mths_since_issue_d:>141        0.0000       NaN
# 94                      int_rate:>20.281        0.0000       NaN
# 95      mths_since_earliest_cr_line:<140        0.0000       NaN
# 96                     inq_last_6mths:>6        0.0000       NaN
# 97                      acc_now_delinq:0        0.0000       NaN
# 98                       annual_inc:<20K        0.0000       NaN
# 99                               dti:>35        0.0000       NaN
# 100           mths_since_last_delinq:0-3        0.0000       NaN
# 101           mths_since_last_record:0-2        0.0000       NaN
#
#            Original feature name  Score - Calculation
# 0                      Intercept             312.8572
# 1                          grade              87.3580
# 2                          grade              68.5438
# 3                          grade              53.5661
# 4                          grade              39.0799
# 5                          grade              25.4791
# 6                          grade              11.0368
# 7                 home_ownership               7.4985
# 8                 home_ownership               8.3681
# 9                     addr_state               2.8289
# 10                    addr_state               4.3119
# 11                    addr_state               4.3595
# 12                    addr_state               4.7475
# 13                    addr_state               5.8156
# 14                    addr_state              10.1957
# 15                    addr_state               7.5013
# 16                    addr_state              14.0582
# 17                    addr_state              17.9358
# 18                    addr_state              16.8653
# 19                    addr_state              19.8836
# 20                    addr_state              24.4509
# 21                    addr_state              39.6379
# 22           verification_status               6.6583
# 23           verification_status              -0.8895
# 24                       purpose              15.4661
# 25                       purpose               7.5490
# 26                       purpose              15.3827
# 27                       purpose              12.7293
# 28           initial_list_status               4.1526
# 29                          term               5.9206
# 30                    emp_length               7.3169
# 31                    emp_length               9.3048
# 32                    emp_length               6.6890
# 33                    emp_length               4.4859
# 34                    emp_length               9.7087
# 35            mths_since_issue_d              83.2364
# 36            mths_since_issue_d              67.5486
# 37            mths_since_issue_d              59.7631
# 38            mths_since_issue_d              44.3063
# 39            mths_since_issue_d              31.9344
# 40            mths_since_issue_d              12.8468
# 41            mths_since_issue_d              -5.9688
# 42                      int_rate              67.1763
# 43                      int_rate              42.3274
# 44                      int_rate              23.0607
# 45                      int_rate               8.4521
# 46   mths_since_earliest_cr_line               5.5786
# 47   mths_since_earliest_cr_line              10.9206
# 48   mths_since_earliest_cr_line              10.4769
# 49   mths_since_earliest_cr_line              13.3965
# 50   mths_since_earliest_cr_line              16.9587
# 51                inq_last_6mths              52.2116
# 52                inq_last_6mths              40.9230
# 53                inq_last_6mths              24.7666
# 54                acc_now_delinq              13.9829
# 55                    annual_inc              -5.9988
# 56                    annual_inc              -1.3102
# 57                    annual_inc               5.9031
# 58                    annual_inc              10.9909
# 59                    annual_inc              16.7904
# 60                    annual_inc              22.4092
# 61                    annual_inc              28.3779
# 62                    annual_inc              29.7999
# 63                    annual_inc              35.7394
# 64                    annual_inc              42.6485
# 65                    annual_inc              37.9462
# 66                           dti              18.8557
# 67                           dti              28.2799
# 68                           dti              29.6755
# 69                           dti              24.8347
# 70                           dti              18.8800
# 71                           dti              11.1866
# 72                           dti              10.1593
# 73                           dti               7.8195
# 74                           dti               4.3905
# 75        mths_since_last_delinq               8.5244
# 76        mths_since_last_delinq              10.7647
# 77        mths_since_last_delinq              14.2603
# 78        mths_since_last_delinq              10.6584
# 79        mths_since_last_record              25.4660
# 80        mths_since_last_record              34.5696
# 81        mths_since_last_record              27.6724
# 82        mths_since_last_record              39.7222
# 83        mths_since_last_record              14.4365
# 84        mths_since_last_record              18.8571
# 85                         grade               0.0000
# 86                home_ownership               0.0000
# 87                    addr_state               0.0000
# 88           verification_status               0.0000
# 89                       purpose               0.0000
# 90           initial_list_status               0.0000
# 91                          term               0.0000
# 92                    emp_length               0.0000
# 93            mths_since_issue_d               0.0000
# 94                      int_rate               0.0000
# 95   mths_since_earliest_cr_line               0.0000
# 96                inq_last_6mths               0.0000
# 97                acc_now_delinq               0.0000
# 98                    annual_inc               0.0000
# 99                           dti               0.0000
# 100       mths_since_last_delinq               0.0000
# 101       mths_since_last_record               0.0000

# %%
df_scorecard['Score - Preliminary'] = df_scorecard['Score - Calculation'].round()
df_scorecard
# Out:
#                             Feature name  Coefficients  p_values  \
# 0                              Intercept       -1.4247       NaN
# 1                                grade:A        1.1410    0.0000
# 2                                grade:B        0.8952    0.0000
# 3                                grade:C        0.6996    0.0000
# 4                                grade:D        0.5104    0.0000
# 5                                grade:E        0.3328    0.0000
# 6                                grade:F        0.1442    0.0034
# 7                     home_ownership:OWN        0.0979    0.0000
# 8                home_ownership:MORTGAGE        0.1093    0.0000
# 9                       addr_state:NM_VA        0.0369    0.2489
# 10                         addr_state:NY        0.0563    0.0201
# 11          addr_state:OK_TN_MO_LA_MD_NC        0.0569    0.0140
# 12                         addr_state:CA        0.0620    0.0035
# 13                addr_state:UT_KY_AZ_NJ        0.0760    0.0023
# 14             addr_state:AR_MI_PA_OH_MN        0.1332    0.0000
# 15             addr_state:RI_MA_DE_SD_IN        0.0980    0.0010
# 16                   addr_state:GA_WA_OR        0.1836    0.0000
# 17                      addr_state:WI_MT        0.2343    0.0000
# 18                         addr_state:TX        0.2203    0.0000
# 19                      addr_state:IL_CT        0.2597    0.0000
# 20          addr_state:KS_SC_CO_VT_AK_MS        0.3194    0.0000
# 21          addr_state:WV_NH_WY_DC_ME_ID        0.5177    0.0000
# 22      verification_status:Not Verified        0.0870    0.0000
# 23   verification_status:Source Verified       -0.0116    0.3871
# 24                   purpose:credit_card        0.2020    0.0000
# 25            purpose:debt_consolidation        0.0986    0.0000
# 26                purpose:RE_med_wed_vac        0.2009    0.0000
# 27         purpose:home_imp__maj_pur_car        0.1663    0.0000
# 28                 initial_list_status:w        0.0542    0.0000
# 29                               term:36        0.0773    0.0000
# 30                          emp_length:1        0.0956    0.0002
# 31                        emp_length:2-4        0.1215    0.0000
# 32                        emp_length:5-6        0.0874    0.0000
# 33                        emp_length:7-9        0.0586    0.0049
# 34                         emp_length:10        0.1268    0.0000
# 35                mths_since_issue_d:<95        1.0871    0.0000
# 36              mths_since_issue_d:95-96        0.8822    0.0000
# 37              mths_since_issue_d:97-98        0.7806    0.0000
# 38             mths_since_issue_d:99-105        0.5787    0.0000
# 39            mths_since_issue_d:106-109        0.4171    0.0000
# 40            mths_since_issue_d:110-121        0.1678    0.0000
# 41            mths_since_issue_d:122-141       -0.0780    0.0077
# 42                       int_rate:<9.548        0.8774    0.0000
# 43                 int_rate:9.548-12.025        0.5528    0.0000
# 44                 int_rate:12.025-15.74        0.3012    0.0000
# 45                 int_rate:15.74-20.281        0.1104    0.0001
# 46   mths_since_earliest_cr_line:141-164        0.0729    0.3726
# 47   mths_since_earliest_cr_line:165-247        0.1426    0.0429
# 48   mths_since_earliest_cr_line:248-270        0.1368    0.0548
# 49   mths_since_earliest_cr_line:271-352        0.1750    0.0131
# 50      mths_since_earliest_cr_line:>352        0.2215    0.0018
# 51                      inq_last_6mths:0        0.6819    0.0000
# 52                    inq_last_6mths:1-2        0.5345    0.0000
# 53                    inq_last_6mths:3-6        0.3235    0.0006
# 54                    acc_now_delinq:>=1        0.1826    0.0845
# 55                    annual_inc:20K-30K       -0.0783    0.0635
# 56                    annual_inc:30K-40K       -0.0171    0.6730
# 57                    annual_inc:40K-50K        0.0771    0.0567
# 58                    annual_inc:50K-60K        0.1436    0.0005
# 59                    annual_inc:60K-70K        0.2193    0.0000
# 60                    annual_inc:70K-80K        0.2927    0.0000
# 61                    annual_inc:80K-90K        0.3706    0.0000
# 62                   annual_inc:90K-100K        0.3892    0.0000
# 63                  annual_inc:100K-120K        0.4668    0.0000
# 64                  annual_inc:120K-140K        0.5570    0.0000
# 65                      annual_inc:>140K        0.4956    0.0000
# 66                             dti:<=1.4        0.2463    0.0034
# 67                           dti:1.4-3.5        0.3694    0.0000
# 68                           dti:3.5-7.7        0.3876    0.0000
# 69                          dti:7.7-10.5        0.3244    0.0000
# 70                         dti:10.5-16.1        0.2466    0.0000
# 71                         dti:16.1-20.3        0.1461    0.0128
# 72                         dti:20.3-21.7        0.1327    0.0305
# 73                         dti:21.7-22.4        0.1021    0.1183
# 74                           dti:22.4-35        0.0573    0.3227
# 75        mths_since_last_delinq:Missing        0.1113    0.0332
# 76           mths_since_last_delinq:4-30        0.1406    0.0077
# 77          mths_since_last_delinq:31-56        0.1863    0.0005
# 78           mths_since_last_delinq:>=57        0.1392    0.0110
# 79        mths_since_last_record:Missing        0.3326    0.0000
# 80           mths_since_last_record:3-20        0.4515    0.0002
# 81          mths_since_last_record:21-31        0.3614    0.0013
# 82          mths_since_last_record:32-80        0.5188    0.0000
# 83          mths_since_last_record:81-86        0.1886    0.0665
# 84            mths_since_last_record:>86        0.2463    0.0036
# 85                               grade:G        0.0000       NaN
# 86    home_ownership:RENT_OTHER_NONE_ANY        0.0000       NaN
# 87       addr_state:ND_NE_IA_NV_FL_HI_AL        0.0000       NaN
# 88          verification_status:Verified        0.0000       NaN
# 89            purpose:sm_bus_edu_mov_hou        0.0000       NaN
# 90                 initial_list_status:f        0.0000       NaN
# 91                               term:60        0.0000       NaN
# 92                          emp_length:0        0.0000       NaN
# 93               mths_since_issue_d:>141        0.0000       NaN
# 94                      int_rate:>20.281        0.0000       NaN
# 95      mths_since_earliest_cr_line:<140        0.0000       NaN
# 96                     inq_last_6mths:>6        0.0000       NaN
# 97                      acc_now_delinq:0        0.0000       NaN
# 98                       annual_inc:<20K        0.0000       NaN
# 99                               dti:>35        0.0000       NaN
# 100           mths_since_last_delinq:0-3        0.0000       NaN
# 101           mths_since_last_record:0-2        0.0000       NaN
#
#            Original feature name  Score - Calculation  Score - Preliminary
# 0                      Intercept             312.8572             313.0000
# 1                          grade              87.3580              87.0000
# 2                          grade              68.5438              69.0000
# 3                          grade              53.5661              54.0000
# 4                          grade              39.0799              39.0000
# 5                          grade              25.4791              25.0000
# 6                          grade              11.0368              11.0000
# 7                 home_ownership               7.4985               7.0000
# 8                 home_ownership               8.3681               8.0000
# 9                     addr_state               2.8289               3.0000
# 10                    addr_state               4.3119               4.0000
# 11                    addr_state               4.3595               4.0000
# 12                    addr_state               4.7475               5.0000
# 13                    addr_state               5.8156               6.0000
# 14                    addr_state              10.1957              10.0000
# 15                    addr_state               7.5013               8.0000
# 16                    addr_state              14.0582              14.0000
# 17                    addr_state              17.9358              18.0000
# 18                    addr_state              16.8653              17.0000
# 19                    addr_state              19.8836              20.0000
# 20                    addr_state              24.4509              24.0000
# 21                    addr_state              39.6379              40.0000
# 22           verification_status               6.6583               7.0000
# 23           verification_status              -0.8895              -1.0000
# 24                       purpose              15.4661              15.0000
# 25                       purpose               7.5490               8.0000
# 26                       purpose              15.3827              15.0000
# 27                       purpose              12.7293              13.0000
# 28           initial_list_status               4.1526               4.0000
# 29                          term               5.9206               6.0000
# 30                    emp_length               7.3169               7.0000
# 31                    emp_length               9.3048               9.0000
# 32                    emp_length               6.6890               7.0000
# 33                    emp_length               4.4859               4.0000
# 34                    emp_length               9.7087              10.0000
# 35            mths_since_issue_d              83.2364              83.0000
# 36            mths_since_issue_d              67.5486              68.0000
# 37            mths_since_issue_d              59.7631              60.0000
# 38            mths_since_issue_d              44.3063              44.0000
# 39            mths_since_issue_d              31.9344              32.0000
# 40            mths_since_issue_d              12.8468              13.0000
# 41            mths_since_issue_d              -5.9688              -6.0000
# 42                      int_rate              67.1763              67.0000
# 43                      int_rate              42.3274              42.0000
# 44                      int_rate              23.0607              23.0000
# 45                      int_rate               8.4521               8.0000
# 46   mths_since_earliest_cr_line               5.5786               6.0000
# 47   mths_since_earliest_cr_line              10.9206              11.0000
# 48   mths_since_earliest_cr_line              10.4769              10.0000
# 49   mths_since_earliest_cr_line              13.3965              13.0000
# 50   mths_since_earliest_cr_line              16.9587              17.0000
# 51                inq_last_6mths              52.2116              52.0000
# 52                inq_last_6mths              40.9230              41.0000
# 53                inq_last_6mths              24.7666              25.0000
# 54                acc_now_delinq              13.9829              14.0000
# 55                    annual_inc              -5.9988              -6.0000
# 56                    annual_inc              -1.3102              -1.0000
# 57                    annual_inc               5.9031               6.0000
# 58                    annual_inc              10.9909              11.0000
# 59                    annual_inc              16.7904              17.0000
# 60                    annual_inc              22.4092              22.0000
# 61                    annual_inc              28.3779              28.0000
# 62                    annual_inc              29.7999              30.0000
# 63                    annual_inc              35.7394              36.0000
# 64                    annual_inc              42.6485              43.0000
# 65                    annual_inc              37.9462              38.0000
# 66                           dti              18.8557              19.0000
# 67                           dti              28.2799              28.0000
# 68                           dti              29.6755              30.0000
# 69                           dti              24.8347              25.0000
# 70                           dti              18.8800              19.0000
# 71                           dti              11.1866              11.0000
# 72                           dti              10.1593              10.0000
# 73                           dti               7.8195               8.0000
# 74                           dti               4.3905               4.0000
# 75        mths_since_last_delinq               8.5244               9.0000
# 76        mths_since_last_delinq              10.7647              11.0000
# 77        mths_since_last_delinq              14.2603              14.0000
# 78        mths_since_last_delinq              10.6584              11.0000
# 79        mths_since_last_record              25.4660              25.0000
# 80        mths_since_last_record              34.5696              35.0000
# 81        mths_since_last_record              27.6724              28.0000
# 82        mths_since_last_record              39.7222              40.0000
# 83        mths_since_last_record              14.4365              14.0000
# 84        mths_since_last_record              18.8571              19.0000
# 85                         grade               0.0000               0.0000
# 86                home_ownership               0.0000               0.0000
# 87                    addr_state               0.0000               0.0000
# 88           verification_status               0.0000               0.0000
# 89                       purpose               0.0000               0.0000
# 90           initial_list_status               0.0000               0.0000
# 91                          term               0.0000               0.0000
# 92                    emp_length               0.0000               0.0000
# 93            mths_since_issue_d               0.0000               0.0000
# 94                      int_rate               0.0000               0.0000
# 95   mths_since_earliest_cr_line               0.0000               0.0000
# 96                inq_last_6mths               0.0000               0.0000
# 97                acc_now_delinq               0.0000               0.0000
# 98                    annual_inc               0.0000               0.0000
# 99                           dti               0.0000               0.0000
# 100       mths_since_last_delinq               0.0000               0.0000
# 101       mths_since_last_record               0.0000               0.0000

# %%
min_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].min().sum()
min_sum_score_prel
# Out:
# 300.0

# %%
max_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].max().sum()
max_sum_score_prel
# Out:
# 850.0

# %%
df_scorecard['Score - Final'] = df_scorecard['Score - Preliminary']
df_scorecard
# Out:
#                             Feature name  Coefficients  p_values  \
# 0                              Intercept       -1.4247       NaN
# 1                                grade:A        1.1410    0.0000
# 2                                grade:B        0.8952    0.0000
# 3                                grade:C        0.6996    0.0000
# 4                                grade:D        0.5104    0.0000
# 5                                grade:E        0.3328    0.0000
# 6                                grade:F        0.1442    0.0034
# 7                     home_ownership:OWN        0.0979    0.0000
# 8                home_ownership:MORTGAGE        0.1093    0.0000
# 9                       addr_state:NM_VA        0.0369    0.2489
# 10                         addr_state:NY        0.0563    0.0201
# 11          addr_state:OK_TN_MO_LA_MD_NC        0.0569    0.0140
# 12                         addr_state:CA        0.0620    0.0035
# 13                addr_state:UT_KY_AZ_NJ        0.0760    0.0023
# 14             addr_state:AR_MI_PA_OH_MN        0.1332    0.0000
# 15             addr_state:RI_MA_DE_SD_IN        0.0980    0.0010
# 16                   addr_state:GA_WA_OR        0.1836    0.0000
# 17                      addr_state:WI_MT        0.2343    0.0000
# 18                         addr_state:TX        0.2203    0.0000
# 19                      addr_state:IL_CT        0.2597    0.0000
# 20          addr_state:KS_SC_CO_VT_AK_MS        0.3194    0.0000
# 21          addr_state:WV_NH_WY_DC_ME_ID        0.5177    0.0000
# 22      verification_status:Not Verified        0.0870    0.0000
# 23   verification_status:Source Verified       -0.0116    0.3871
# 24                   purpose:credit_card        0.2020    0.0000
# 25            purpose:debt_consolidation        0.0986    0.0000
# 26                purpose:RE_med_wed_vac        0.2009    0.0000
# 27         purpose:home_imp__maj_pur_car        0.1663    0.0000
# 28                 initial_list_status:w        0.0542    0.0000
# 29                               term:36        0.0773    0.0000
# 30                          emp_length:1        0.0956    0.0002
# 31                        emp_length:2-4        0.1215    0.0000
# 32                        emp_length:5-6        0.0874    0.0000
# 33                        emp_length:7-9        0.0586    0.0049
# 34                         emp_length:10        0.1268    0.0000
# 35                mths_since_issue_d:<95        1.0871    0.0000
# 36              mths_since_issue_d:95-96        0.8822    0.0000
# 37              mths_since_issue_d:97-98        0.7806    0.0000
# 38             mths_since_issue_d:99-105        0.5787    0.0000
# 39            mths_since_issue_d:106-109        0.4171    0.0000
# 40            mths_since_issue_d:110-121        0.1678    0.0000
# 41            mths_since_issue_d:122-141       -0.0780    0.0077
# 42                       int_rate:<9.548        0.8774    0.0000
# 43                 int_rate:9.548-12.025        0.5528    0.0000
# 44                 int_rate:12.025-15.74        0.3012    0.0000
# 45                 int_rate:15.74-20.281        0.1104    0.0001
# 46   mths_since_earliest_cr_line:141-164        0.0729    0.3726
# 47   mths_since_earliest_cr_line:165-247        0.1426    0.0429
# 48   mths_since_earliest_cr_line:248-270        0.1368    0.0548
# 49   mths_since_earliest_cr_line:271-352        0.1750    0.0131
# 50      mths_since_earliest_cr_line:>352        0.2215    0.0018
# 51                      inq_last_6mths:0        0.6819    0.0000
# 52                    inq_last_6mths:1-2        0.5345    0.0000
# 53                    inq_last_6mths:3-6        0.3235    0.0006
# 54                    acc_now_delinq:>=1        0.1826    0.0845
# 55                    annual_inc:20K-30K       -0.0783    0.0635
# 56                    annual_inc:30K-40K       -0.0171    0.6730
# 57                    annual_inc:40K-50K        0.0771    0.0567
# 58                    annual_inc:50K-60K        0.1436    0.0005
# 59                    annual_inc:60K-70K        0.2193    0.0000
# 60                    annual_inc:70K-80K        0.2927    0.0000
# 61                    annual_inc:80K-90K        0.3706    0.0000
# 62                   annual_inc:90K-100K        0.3892    0.0000
# 63                  annual_inc:100K-120K        0.4668    0.0000
# 64                  annual_inc:120K-140K        0.5570    0.0000
# 65                      annual_inc:>140K        0.4956    0.0000
# 66                             dti:<=1.4        0.2463    0.0034
# 67                           dti:1.4-3.5        0.3694    0.0000
# 68                           dti:3.5-7.7        0.3876    0.0000
# 69                          dti:7.7-10.5        0.3244    0.0000
# 70                         dti:10.5-16.1        0.2466    0.0000
# 71                         dti:16.1-20.3        0.1461    0.0128
# 72                         dti:20.3-21.7        0.1327    0.0305
# 73                         dti:21.7-22.4        0.1021    0.1183
# 74                           dti:22.4-35        0.0573    0.3227
# 75        mths_since_last_delinq:Missing        0.1113    0.0332
# 76           mths_since_last_delinq:4-30        0.1406    0.0077
# 77          mths_since_last_delinq:31-56        0.1863    0.0005
# 78           mths_since_last_delinq:>=57        0.1392    0.0110
# 79        mths_since_last_record:Missing        0.3326    0.0000
# 80           mths_since_last_record:3-20        0.4515    0.0002
# 81          mths_since_last_record:21-31        0.3614    0.0013
# 82          mths_since_last_record:32-80        0.5188    0.0000
# 83          mths_since_last_record:81-86        0.1886    0.0665
# 84            mths_since_last_record:>86        0.2463    0.0036
# 85                               grade:G        0.0000       NaN
# 86    home_ownership:RENT_OTHER_NONE_ANY        0.0000       NaN
# 87       addr_state:ND_NE_IA_NV_FL_HI_AL        0.0000       NaN
# 88          verification_status:Verified        0.0000       NaN
# 89            purpose:sm_bus_edu_mov_hou        0.0000       NaN
# 90                 initial_list_status:f        0.0000       NaN
# 91                               term:60        0.0000       NaN
# 92                          emp_length:0        0.0000       NaN
# 93               mths_since_issue_d:>141        0.0000       NaN
# 94                      int_rate:>20.281        0.0000       NaN
# 95      mths_since_earliest_cr_line:<140        0.0000       NaN
# 96                     inq_last_6mths:>6        0.0000       NaN
# 97                      acc_now_delinq:0        0.0000       NaN
# 98                       annual_inc:<20K        0.0000       NaN
# 99                               dti:>35        0.0000       NaN
# 100           mths_since_last_delinq:0-3        0.0000       NaN
# 101           mths_since_last_record:0-2        0.0000       NaN
#
#            Original feature name  Score - Calculation  Score - Preliminary  \
# 0                      Intercept             312.8572             313.0000
# 1                          grade              87.3580              87.0000
# 2                          grade              68.5438              69.0000
# 3                          grade              53.5661              54.0000
# 4                          grade              39.0799              39.0000
# 5                          grade              25.4791              25.0000
# 6                          grade              11.0368              11.0000
# 7                 home_ownership               7.4985               7.0000
# 8                 home_ownership               8.3681               8.0000
# 9                     addr_state               2.8289               3.0000
# 10                    addr_state               4.3119               4.0000
# 11                    addr_state               4.3595               4.0000
# 12                    addr_state               4.7475               5.0000
# 13                    addr_state               5.8156               6.0000
# 14                    addr_state              10.1957              10.0000
# 15                    addr_state               7.5013               8.0000
# 16                    addr_state              14.0582              14.0000
# 17                    addr_state              17.9358              18.0000
# 18                    addr_state              16.8653              17.0000
# 19                    addr_state              19.8836              20.0000
# 20                    addr_state              24.4509              24.0000
# 21                    addr_state              39.6379              40.0000
# 22           verification_status               6.6583               7.0000
# 23           verification_status              -0.8895              -1.0000
# 24                       purpose              15.4661              15.0000
# 25                       purpose               7.5490               8.0000
# 26                       purpose              15.3827              15.0000
# 27                       purpose              12.7293              13.0000
# 28           initial_list_status               4.1526               4.0000
# 29                          term               5.9206               6.0000
# 30                    emp_length               7.3169               7.0000
# 31                    emp_length               9.3048               9.0000
# 32                    emp_length               6.6890               7.0000
# 33                    emp_length               4.4859               4.0000
# 34                    emp_length               9.7087              10.0000
# 35            mths_since_issue_d              83.2364              83.0000
# 36            mths_since_issue_d              67.5486              68.0000
# 37            mths_since_issue_d              59.7631              60.0000
# 38            mths_since_issue_d              44.3063              44.0000
# 39            mths_since_issue_d              31.9344              32.0000
# 40            mths_since_issue_d              12.8468              13.0000
# 41            mths_since_issue_d              -5.9688              -6.0000
# 42                      int_rate              67.1763              67.0000
# 43                      int_rate              42.3274              42.0000
# 44                      int_rate              23.0607              23.0000
# 45                      int_rate               8.4521               8.0000
# 46   mths_since_earliest_cr_line               5.5786               6.0000
# 47   mths_since_earliest_cr_line              10.9206              11.0000
# 48   mths_since_earliest_cr_line              10.4769              10.0000
# 49   mths_since_earliest_cr_line              13.3965              13.0000
# 50   mths_since_earliest_cr_line              16.9587              17.0000
# 51                inq_last_6mths              52.2116              52.0000
# 52                inq_last_6mths              40.9230              41.0000
# 53                inq_last_6mths              24.7666              25.0000
# 54                acc_now_delinq              13.9829              14.0000
# 55                    annual_inc              -5.9988              -6.0000
# 56                    annual_inc              -1.3102              -1.0000
# 57                    annual_inc               5.9031               6.0000
# 58                    annual_inc              10.9909              11.0000
# 59                    annual_inc              16.7904              17.0000
# 60                    annual_inc              22.4092              22.0000
# 61                    annual_inc              28.3779              28.0000
# 62                    annual_inc              29.7999              30.0000
# 63                    annual_inc              35.7394              36.0000
# 64                    annual_inc              42.6485              43.0000
# 65                    annual_inc              37.9462              38.0000
# 66                           dti              18.8557              19.0000
# 67                           dti              28.2799              28.0000
# 68                           dti              29.6755              30.0000
# 69                           dti              24.8347              25.0000
# 70                           dti              18.8800              19.0000
# 71                           dti              11.1866              11.0000
# 72                           dti              10.1593              10.0000
# 73                           dti               7.8195               8.0000
# 74                           dti               4.3905               4.0000
# 75        mths_since_last_delinq               8.5244               9.0000
# 76        mths_since_last_delinq              10.7647              11.0000
# 77        mths_since_last_delinq              14.2603              14.0000
# 78        mths_since_last_delinq              10.6584              11.0000
# 79        mths_since_last_record              25.4660              25.0000
# 80        mths_since_last_record              34.5696              35.0000
# 81        mths_since_last_record              27.6724              28.0000
# 82        mths_since_last_record              39.7222              40.0000
# 83        mths_since_last_record              14.4365              14.0000
# 84        mths_since_last_record              18.8571              19.0000
# 85                         grade               0.0000               0.0000
# 86                home_ownership               0.0000               0.0000
# 87                    addr_state               0.0000               0.0000
# 88           verification_status               0.0000               0.0000
# 89                       purpose               0.0000               0.0000
# 90           initial_list_status               0.0000               0.0000
# 91                          term               0.0000               0.0000
# 92                    emp_length               0.0000               0.0000
# 93            mths_since_issue_d               0.0000               0.0000
# 94                      int_rate               0.0000               0.0000
# 95   mths_since_earliest_cr_line               0.0000               0.0000
# 96                inq_last_6mths               0.0000               0.0000
# 97                acc_now_delinq               0.0000               0.0000
# 98                    annual_inc               0.0000               0.0000
# 99                           dti               0.0000               0.0000
# 100       mths_since_last_delinq               0.0000               0.0000
# 101       mths_since_last_record               0.0000               0.0000
#
#      Score - Final
# 0         313.0000
# 1          87.0000
# 2          69.0000
# 3          54.0000
# 4          39.0000
# 5          25.0000
# 6          11.0000
# 7           7.0000
# 8           8.0000
# 9           3.0000
# 10          4.0000
# 11          4.0000
# 12          5.0000
# 13          6.0000
# 14         10.0000
# 15          8.0000
# 16         14.0000
# 17         18.0000
# 18         17.0000
# 19         20.0000
# 20         24.0000
# 21         40.0000
# 22          7.0000
# 23         -1.0000
# 24         15.0000
# 25          8.0000
# 26         15.0000
# 27         13.0000
# 28          4.0000
# 29          6.0000
# 30          7.0000
# 31          9.0000
# 32          7.0000
# 33          4.0000
# 34         10.0000
# 35         83.0000
# 36         68.0000
# 37         60.0000
# 38         44.0000
# 39         32.0000
# 40         13.0000
# 41         -6.0000
# 42         67.0000
# 43         42.0000
# 44         23.0000
# 45          8.0000
# 46          6.0000
# 47         11.0000
# 48         10.0000
# 49         13.0000
# 50         17.0000
# 51         52.0000
# 52         41.0000
# 53         25.0000
# 54         14.0000
# 55         -6.0000
# 56         -1.0000
# 57          6.0000
# 58         11.0000
# 59         17.0000
# 60         22.0000
# 61         28.0000
# 62         30.0000
# 63         36.0000
# 64         43.0000
# 65         38.0000
# 66         19.0000
# 67         28.0000
# 68         30.0000
# 69         25.0000
# 70         19.0000
# 71         11.0000
# 72         10.0000
# 73          8.0000
# 74          4.0000
# 75          9.0000
# 76         11.0000
# 77         14.0000
# 78         11.0000
# 79         25.0000
# 80         35.0000
# 81         28.0000
# 82         40.0000
# 83         14.0000
# 84         19.0000
# 85          0.0000
# 86          0.0000
# 87          0.0000
# 88          0.0000
# 89          0.0000
# 90          0.0000
# 91          0.0000
# 92          0.0000
# 93          0.0000
# 94          0.0000
# 95          0.0000
# 96          0.0000
# 97          0.0000
# 98          0.0000
# 99          0.0000
# 100         0.0000
# 101         0.0000

# %% [markdown]
# ### Caclulating Credit Score

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 362514        0        0        1        0        0        0        0
# 288564        0        0        0        0        1        0        0
# 213591        0        0        1        0        0        0        0
# 263083        0        0        1        0        0        0        0
# 165001        1        0        0        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514                                   0                   0
# 288564                                   0                   0
# 213591                                   0                   0
# 263083                                   0                   0
# 165001                                   0                   0
#
#         home_ownership:MORTGAGE  ...  mths_since_last_delinq:4-30  \
# 362514                        1  ...                            0
# 288564                        1  ...                            0
# 213591                        1  ...                            0
# 263083                        1  ...                            0
# 165001                        1  ...                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 362514                             0                            0
# 288564                             0                            0
# 213591                             1                            0
# 263083                             0                            0
# 165001                             1                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:0-2  \
# 362514                               1                           0
# 288564                               1                           0
# 213591                               1                           0
# 263083                               1                           0
# 165001                               1                           0
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             0
# 263083                            0                             0
# 165001                            0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:>86
# 362514                           0
# 288564                           0
# 213591                           0
# 263083                           0
# 165001                           0
#
# [5 rows x 101 columns]

# %%
df_scorecard
# Out:
#                             Feature name  Coefficients  p_values  \
# 0                              Intercept       -1.4247       NaN
# 1                                grade:A        1.1410    0.0000
# 2                                grade:B        0.8952    0.0000
# 3                                grade:C        0.6996    0.0000
# 4                                grade:D        0.5104    0.0000
# 5                                grade:E        0.3328    0.0000
# 6                                grade:F        0.1442    0.0034
# 7                     home_ownership:OWN        0.0979    0.0000
# 8                home_ownership:MORTGAGE        0.1093    0.0000
# 9                       addr_state:NM_VA        0.0369    0.2489
# 10                         addr_state:NY        0.0563    0.0201
# 11          addr_state:OK_TN_MO_LA_MD_NC        0.0569    0.0140
# 12                         addr_state:CA        0.0620    0.0035
# 13                addr_state:UT_KY_AZ_NJ        0.0760    0.0023
# 14             addr_state:AR_MI_PA_OH_MN        0.1332    0.0000
# 15             addr_state:RI_MA_DE_SD_IN        0.0980    0.0010
# 16                   addr_state:GA_WA_OR        0.1836    0.0000
# 17                      addr_state:WI_MT        0.2343    0.0000
# 18                         addr_state:TX        0.2203    0.0000
# 19                      addr_state:IL_CT        0.2597    0.0000
# 20          addr_state:KS_SC_CO_VT_AK_MS        0.3194    0.0000
# 21          addr_state:WV_NH_WY_DC_ME_ID        0.5177    0.0000
# 22      verification_status:Not Verified        0.0870    0.0000
# 23   verification_status:Source Verified       -0.0116    0.3871
# 24                   purpose:credit_card        0.2020    0.0000
# 25            purpose:debt_consolidation        0.0986    0.0000
# 26                purpose:RE_med_wed_vac        0.2009    0.0000
# 27         purpose:home_imp__maj_pur_car        0.1663    0.0000
# 28                 initial_list_status:w        0.0542    0.0000
# 29                               term:36        0.0773    0.0000
# 30                          emp_length:1        0.0956    0.0002
# 31                        emp_length:2-4        0.1215    0.0000
# 32                        emp_length:5-6        0.0874    0.0000
# 33                        emp_length:7-9        0.0586    0.0049
# 34                         emp_length:10        0.1268    0.0000
# 35                mths_since_issue_d:<95        1.0871    0.0000
# 36              mths_since_issue_d:95-96        0.8822    0.0000
# 37              mths_since_issue_d:97-98        0.7806    0.0000
# 38             mths_since_issue_d:99-105        0.5787    0.0000
# 39            mths_since_issue_d:106-109        0.4171    0.0000
# 40            mths_since_issue_d:110-121        0.1678    0.0000
# 41            mths_since_issue_d:122-141       -0.0780    0.0077
# 42                       int_rate:<9.548        0.8774    0.0000
# 43                 int_rate:9.548-12.025        0.5528    0.0000
# 44                 int_rate:12.025-15.74        0.3012    0.0000
# 45                 int_rate:15.74-20.281        0.1104    0.0001
# 46   mths_since_earliest_cr_line:141-164        0.0729    0.3726
# 47   mths_since_earliest_cr_line:165-247        0.1426    0.0429
# 48   mths_since_earliest_cr_line:248-270        0.1368    0.0548
# 49   mths_since_earliest_cr_line:271-352        0.1750    0.0131
# 50      mths_since_earliest_cr_line:>352        0.2215    0.0018
# 51                      inq_last_6mths:0        0.6819    0.0000
# 52                    inq_last_6mths:1-2        0.5345    0.0000
# 53                    inq_last_6mths:3-6        0.3235    0.0006
# 54                    acc_now_delinq:>=1        0.1826    0.0845
# 55                    annual_inc:20K-30K       -0.0783    0.0635
# 56                    annual_inc:30K-40K       -0.0171    0.6730
# 57                    annual_inc:40K-50K        0.0771    0.0567
# 58                    annual_inc:50K-60K        0.1436    0.0005
# 59                    annual_inc:60K-70K        0.2193    0.0000
# 60                    annual_inc:70K-80K        0.2927    0.0000
# 61                    annual_inc:80K-90K        0.3706    0.0000
# 62                   annual_inc:90K-100K        0.3892    0.0000
# 63                  annual_inc:100K-120K        0.4668    0.0000
# 64                  annual_inc:120K-140K        0.5570    0.0000
# 65                      annual_inc:>140K        0.4956    0.0000
# 66                             dti:<=1.4        0.2463    0.0034
# 67                           dti:1.4-3.5        0.3694    0.0000
# 68                           dti:3.5-7.7        0.3876    0.0000
# 69                          dti:7.7-10.5        0.3244    0.0000
# 70                         dti:10.5-16.1        0.2466    0.0000
# 71                         dti:16.1-20.3        0.1461    0.0128
# 72                         dti:20.3-21.7        0.1327    0.0305
# 73                         dti:21.7-22.4        0.1021    0.1183
# 74                           dti:22.4-35        0.0573    0.3227
# 75        mths_since_last_delinq:Missing        0.1113    0.0332
# 76           mths_since_last_delinq:4-30        0.1406    0.0077
# 77          mths_since_last_delinq:31-56        0.1863    0.0005
# 78           mths_since_last_delinq:>=57        0.1392    0.0110
# 79        mths_since_last_record:Missing        0.3326    0.0000
# 80           mths_since_last_record:3-20        0.4515    0.0002
# 81          mths_since_last_record:21-31        0.3614    0.0013
# 82          mths_since_last_record:32-80        0.5188    0.0000
# 83          mths_since_last_record:81-86        0.1886    0.0665
# 84            mths_since_last_record:>86        0.2463    0.0036
# 85                               grade:G        0.0000       NaN
# 86    home_ownership:RENT_OTHER_NONE_ANY        0.0000       NaN
# 87       addr_state:ND_NE_IA_NV_FL_HI_AL        0.0000       NaN
# 88          verification_status:Verified        0.0000       NaN
# 89            purpose:sm_bus_edu_mov_hou        0.0000       NaN
# 90                 initial_list_status:f        0.0000       NaN
# 91                               term:60        0.0000       NaN
# 92                          emp_length:0        0.0000       NaN
# 93               mths_since_issue_d:>141        0.0000       NaN
# 94                      int_rate:>20.281        0.0000       NaN
# 95      mths_since_earliest_cr_line:<140        0.0000       NaN
# 96                     inq_last_6mths:>6        0.0000       NaN
# 97                      acc_now_delinq:0        0.0000       NaN
# 98                       annual_inc:<20K        0.0000       NaN
# 99                               dti:>35        0.0000       NaN
# 100           mths_since_last_delinq:0-3        0.0000       NaN
# 101           mths_since_last_record:0-2        0.0000       NaN
#
#            Original feature name  Score - Calculation  Score - Preliminary  \
# 0                      Intercept             312.8572             313.0000
# 1                          grade              87.3580              87.0000
# 2                          grade              68.5438              69.0000
# 3                          grade              53.5661              54.0000
# 4                          grade              39.0799              39.0000
# 5                          grade              25.4791              25.0000
# 6                          grade              11.0368              11.0000
# 7                 home_ownership               7.4985               7.0000
# 8                 home_ownership               8.3681               8.0000
# 9                     addr_state               2.8289               3.0000
# 10                    addr_state               4.3119               4.0000
# 11                    addr_state               4.3595               4.0000
# 12                    addr_state               4.7475               5.0000
# 13                    addr_state               5.8156               6.0000
# 14                    addr_state              10.1957              10.0000
# 15                    addr_state               7.5013               8.0000
# 16                    addr_state              14.0582              14.0000
# 17                    addr_state              17.9358              18.0000
# 18                    addr_state              16.8653              17.0000
# 19                    addr_state              19.8836              20.0000
# 20                    addr_state              24.4509              24.0000
# 21                    addr_state              39.6379              40.0000
# 22           verification_status               6.6583               7.0000
# 23           verification_status              -0.8895              -1.0000
# 24                       purpose              15.4661              15.0000
# 25                       purpose               7.5490               8.0000
# 26                       purpose              15.3827              15.0000
# 27                       purpose              12.7293              13.0000
# 28           initial_list_status               4.1526               4.0000
# 29                          term               5.9206               6.0000
# 30                    emp_length               7.3169               7.0000
# 31                    emp_length               9.3048               9.0000
# 32                    emp_length               6.6890               7.0000
# 33                    emp_length               4.4859               4.0000
# 34                    emp_length               9.7087              10.0000
# 35            mths_since_issue_d              83.2364              83.0000
# 36            mths_since_issue_d              67.5486              68.0000
# 37            mths_since_issue_d              59.7631              60.0000
# 38            mths_since_issue_d              44.3063              44.0000
# 39            mths_since_issue_d              31.9344              32.0000
# 40            mths_since_issue_d              12.8468              13.0000
# 41            mths_since_issue_d              -5.9688              -6.0000
# 42                      int_rate              67.1763              67.0000
# 43                      int_rate              42.3274              42.0000
# 44                      int_rate              23.0607              23.0000
# 45                      int_rate               8.4521               8.0000
# 46   mths_since_earliest_cr_line               5.5786               6.0000
# 47   mths_since_earliest_cr_line              10.9206              11.0000
# 48   mths_since_earliest_cr_line              10.4769              10.0000
# 49   mths_since_earliest_cr_line              13.3965              13.0000
# 50   mths_since_earliest_cr_line              16.9587              17.0000
# 51                inq_last_6mths              52.2116              52.0000
# 52                inq_last_6mths              40.9230              41.0000
# 53                inq_last_6mths              24.7666              25.0000
# 54                acc_now_delinq              13.9829              14.0000
# 55                    annual_inc              -5.9988              -6.0000
# 56                    annual_inc              -1.3102              -1.0000
# 57                    annual_inc               5.9031               6.0000
# 58                    annual_inc              10.9909              11.0000
# 59                    annual_inc              16.7904              17.0000
# 60                    annual_inc              22.4092              22.0000
# 61                    annual_inc              28.3779              28.0000
# 62                    annual_inc              29.7999              30.0000
# 63                    annual_inc              35.7394              36.0000
# 64                    annual_inc              42.6485              43.0000
# 65                    annual_inc              37.9462              38.0000
# 66                           dti              18.8557              19.0000
# 67                           dti              28.2799              28.0000
# 68                           dti              29.6755              30.0000
# 69                           dti              24.8347              25.0000
# 70                           dti              18.8800              19.0000
# 71                           dti              11.1866              11.0000
# 72                           dti              10.1593              10.0000
# 73                           dti               7.8195               8.0000
# 74                           dti               4.3905               4.0000
# 75        mths_since_last_delinq               8.5244               9.0000
# 76        mths_since_last_delinq              10.7647              11.0000
# 77        mths_since_last_delinq              14.2603              14.0000
# 78        mths_since_last_delinq              10.6584              11.0000
# 79        mths_since_last_record              25.4660              25.0000
# 80        mths_since_last_record              34.5696              35.0000
# 81        mths_since_last_record              27.6724              28.0000
# 82        mths_since_last_record              39.7222              40.0000
# 83        mths_since_last_record              14.4365              14.0000
# 84        mths_since_last_record              18.8571              19.0000
# 85                         grade               0.0000               0.0000
# 86                home_ownership               0.0000               0.0000
# 87                    addr_state               0.0000               0.0000
# 88           verification_status               0.0000               0.0000
# 89                       purpose               0.0000               0.0000
# 90           initial_list_status               0.0000               0.0000
# 91                          term               0.0000               0.0000
# 92                    emp_length               0.0000               0.0000
# 93            mths_since_issue_d               0.0000               0.0000
# 94                      int_rate               0.0000               0.0000
# 95   mths_since_earliest_cr_line               0.0000               0.0000
# 96                inq_last_6mths               0.0000               0.0000
# 97                acc_now_delinq               0.0000               0.0000
# 98                    annual_inc               0.0000               0.0000
# 99                           dti               0.0000               0.0000
# 100       mths_since_last_delinq               0.0000               0.0000
# 101       mths_since_last_record               0.0000               0.0000
#
#      Score - Final
# 0         313.0000
# 1          87.0000
# 2          69.0000
# 3          54.0000
# 4          39.0000
# 5          25.0000
# 6          11.0000
# 7           7.0000
# 8           8.0000
# 9           3.0000
# 10          4.0000
# 11          4.0000
# 12          5.0000
# 13          6.0000
# 14         10.0000
# 15          8.0000
# 16         14.0000
# 17         18.0000
# 18         17.0000
# 19         20.0000
# 20         24.0000
# 21         40.0000
# 22          7.0000
# 23         -1.0000
# 24         15.0000
# 25          8.0000
# 26         15.0000
# 27         13.0000
# 28          4.0000
# 29          6.0000
# 30          7.0000
# 31          9.0000
# 32          7.0000
# 33          4.0000
# 34         10.0000
# 35         83.0000
# 36         68.0000
# 37         60.0000
# 38         44.0000
# 39         32.0000
# 40         13.0000
# 41         -6.0000
# 42         67.0000
# 43         42.0000
# 44         23.0000
# 45          8.0000
# 46          6.0000
# 47         11.0000
# 48         10.0000
# 49         13.0000
# 50         17.0000
# 51         52.0000
# 52         41.0000
# 53         25.0000
# 54         14.0000
# 55         -6.0000
# 56         -1.0000
# 57          6.0000
# 58         11.0000
# 59         17.0000
# 60         22.0000
# 61         28.0000
# 62         30.0000
# 63         36.0000
# 64         43.0000
# 65         38.0000
# 66         19.0000
# 67         28.0000
# 68         30.0000
# 69         25.0000
# 70         19.0000
# 71         11.0000
# 72         10.0000
# 73          8.0000
# 74          4.0000
# 75          9.0000
# 76         11.0000
# 77         14.0000
# 78         11.0000
# 79         25.0000
# 80         35.0000
# 81         28.0000
# 82         40.0000
# 83         14.0000
# 84         19.0000
# 85          0.0000
# 86          0.0000
# 87          0.0000
# 88          0.0000
# 89          0.0000
# 90          0.0000
# 91          0.0000
# 92          0.0000
# 93          0.0000
# 94          0.0000
# 95          0.0000
# 96          0.0000
# 97          0.0000
# 98          0.0000
# 99          0.0000
# 100         0.0000
# 101         0.0000

# %%
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat

# %%
inputs_test_with_ref_cat_w_intercept.insert(0, 'Intercept', 1)

# %%
inputs_test_with_ref_cat_w_intercept.head()
# Out:
#         Intercept  grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514          1        0        0        1        0        0        0
# 288564          1        0        0        0        0        1        0
# 213591          1        0        0        1        0        0        0
# 263083          1        0        0        1        0        0        0
# 165001          1        1        0        0        0        0        0
#
#         grade:G  home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  ...  \
# 362514        0                                   0                   0  ...
# 288564        0                                   0                   0  ...
# 213591        0                                   0                   0  ...
# 263083        0                                   0                   0  ...
# 165001        0                                   0                   0  ...
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:0-2  mths_since_last_record:3-20  \
# 362514                           0                            0
# 288564                           0                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>86
# 362514                             0                           0
# 288564                             0                           0
# 213591                             0                           0
# 263083                             0                           0
# 165001                             0                           0
#
# [5 rows x 102 columns]

# %% [markdown]
# Here, from the 'inputs_test_with_ref_cat_w_intercept' dataframe, we keep only the columns with column names, exactly equal to the row values of the 'Feature name' column from the 'df_scorecard' dataframe.

# %%
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat_w_intercept[df_scorecard['Feature name'].values]

# %%
inputs_test_with_ref_cat_w_intercept.head()
# Out:
#         Intercept  grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514          1        0        0        1        0        0        0
# 288564          1        0        0        0        0        1        0
# 213591          1        0        0        1        0        0        0
# 263083          1        0        0        1        0        0        0
# 165001          1        1        0        0        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  ...  \
# 362514                   0                        1                 0  ...
# 288564                   0                        1                 0  ...
# 213591                   0                        1                 0  ...
# 263083                   0                        1                 0  ...
# 165001                   0                        1                 0  ...
#
#         emp_length:0  mths_since_issue_d:>141  int_rate:>20.281  \
# 362514             1                        0                 0
# 288564             0                        0                 1
# 213591             0                        0                 0
# 263083             0                        0                 0
# 165001             0                        0                 0
#
#         mths_since_earliest_cr_line:<140  inq_last_6mths:>6  acc_now_delinq:0  \
# 362514                                 0                  0                 1
# 288564                                 0                  0                 1
# 213591                                 0                  0                 1
# 263083                                 0                  0                 1
# 165001                                 0                  0                 1
#
#         annual_inc:<20K  dti:>35  mths_since_last_delinq:0-3  \
# 362514                0        0                           0
# 288564                0        0                           1
# 213591                0        0                           0
# 263083                0        0                           0
# 165001                0        0                           0
#
#         mths_since_last_record:0-2
# 362514                           0
# 288564                           0
# 213591                           0
# 263083                           0
# 165001                           0
#
# [5 rows x 102 columns]

# %%
scorecard_scores = df_scorecard['Score - Final']

# %%
inputs_test_with_ref_cat_w_intercept.shape
# Out:
# (93257, 102)

# %%
scorecard_scores.shape
# Out:
# (102,)

# %%
scorecard_scores = scorecard_scores.values.reshape(102, 1)

# %%
scorecard_scores.shape
# Out:
# (102, 1)

# %%
y_scores = inputs_test_with_ref_cat_w_intercept.dot(scorecard_scores)

# %%
y_scores.head()
# Out:
#               0
# 362514 615.0000
# 288564 554.0000
# 213591 578.0000
# 263083 636.0000
# 165001 683.0000

# %% [markdown]
# ### From Credit Score to PD

# %%
sum_coef_from_score = ((y_scores - min_score) / (max_score - min_score)) * (max_sum_coef - min_sum_coef) + min_sum_coef

# %%
y_hat_proba_from_score = np.exp(sum_coef_from_score) / (np.exp(sum_coef_from_score) + 1)
y_hat_proba_from_score.head()
# Out:
#             0
# 362514 0.9256
# 288564 0.8488
# 213591 0.8848
# 263083 0.9425
# 165001 0.9680

# %%
y_hat_test_proba[0: 5]
# Out:
# array([0.92459032, 0.85052453, 0.88498828, 0.94280473, 0.96844444])

# %% [markdown]
# ### Setting Cut-offs

# %%
tr = 0.9
df_actual_predicted_probs['y_hat_test'] = np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1, 0)

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted      0      1
# Actual
# 0           7367   2823
# 1          35857  47210

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]
# Out:
# Predicted      0      1
# Actual
# 0         0.0790 0.0303
# 1         0.3845 0.5062

# %%
(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[0, 0] + (pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[1, 1]
# Out:
# 0.5852322077699261

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Out:
# (array([0.        , 0.        , 0.        , ..., 0.99950932, 1.        ,
#         1.        ]),
#  array([0.00000000e+00, 1.20384750e-05, 2.52807974e-04, ...,
#         9.99975923e-01, 9.99975923e-01, 1.00000000e+00]),
#  array([1.99266221, 0.99266221, 0.99023263, ..., 0.4842736 , 0.4422138 ,
#         0.36463858]))

# %%
fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %%
thresholds
# Out:
# array([1.99266221, 0.99266221, 0.99023263, ..., 0.4842736 , 0.4422138 ,
#        0.36463858])

# %%
thresholds.shape
# Out:
# (17454,)

# %%
df_cutoffs = pd.concat([pd.DataFrame(thresholds), pd.DataFrame(fpr), pd.DataFrame(tpr)], axis = 1)

# %%
df_cutoffs.columns = ['thresholds', 'fpr', 'tpr']

# %%
df_cutoffs.head()
# Out:
#    thresholds    fpr    tpr
# 0      1.9927 0.0000 0.0000
# 1      0.9927 0.0000 0.0000
# 2      0.9902 0.0000 0.0003
# 3      0.9902 0.0001 0.0003
# 4      0.9897 0.0001 0.0005

# %%
df_cutoffs['thresholds'][0] = 1 - 1 / np.power(10, 16)

# %%
df_cutoffs['Score'] = ((np.log(df_cutoffs['thresholds'] / (1 - df_cutoffs['thresholds'])) - min_sum_coef) * ((max_score - min_score) / (max_sum_coef - min_sum_coef)) + min_score).round()

# %%
df_cutoffs.head()
# Out:
#    thresholds    fpr    tpr     Score
# 0      1.0000 0.0000 0.0000 2057.0000
# 1      0.9927 0.0000 0.0000  798.0000
# 2      0.9902 0.0000 0.0003  776.0000
# 3      0.9902 0.0001 0.0003  775.0000
# 4      0.9897 0.0001 0.0005  771.0000

# %%
df_cutoffs['Score'][0] = max_score

# %%
df_cutoffs.head()
# Out:
#    thresholds    fpr    tpr    Score
# 0      1.0000 0.0000 0.0000 850.0000
# 1      0.9927 0.0000 0.0000 798.0000
# 2      0.9902 0.0000 0.0003 776.0000
# 3      0.9902 0.0001 0.0003 775.0000
# 4      0.9897 0.0001 0.0005 771.0000

# %%
def n_approved(p):
    return np.where(df_actual_predicted_probs['y_hat_test_proba'] >= p, 1, 0).sum()

# %%
df_cutoffs['N Approved'] = df_cutoffs['thresholds'].apply(n_approved)
df_cutoffs['N Rejected'] = df_actual_predicted_probs['y_hat_test_proba'].shape[0] - df_cutoffs['N Approved']
df_cutoffs['Approval Rate'] = df_cutoffs['N Approved'] / df_actual_predicted_probs['y_hat_test_proba'].shape[0]
df_cutoffs['Rejection Rate'] = 1 - df_cutoffs['Approval Rate']

# %%
df_cutoffs.head()
# Out:
#    thresholds    fpr    tpr    Score  N Approved  N Rejected  Approval Rate  \
# 0      1.0000 0.0000 0.0000 850.0000           0       93257         0.0000
# 1      0.9927 0.0000 0.0000 798.0000           1       93256         0.0000
# 2      0.9902 0.0000 0.0003 776.0000          21       93236         0.0002
# 3      0.9902 0.0001 0.0003 775.0000          22       93235         0.0002
# 4      0.9897 0.0001 0.0005 771.0000          41       93216         0.0004
#
#    Rejection Rate
# 0          1.0000
# 1          1.0000
# 2          0.9998
# 3          0.9998
# 4          0.9996

# %%
df_cutoffs.iloc[5000: 6200, ]
# Out:
#       thresholds    fpr    tpr    Score  N Approved  N Rejected  \
# 5000      0.9043 0.2547 0.5425 594.0000       47663       45594
# 5001      0.9043 0.2547 0.5428 594.0000       47686       45571
# 5002      0.9043 0.2548 0.5428 594.0000       47687       45570
# 5003      0.9042 0.2548 0.5429 594.0000       47693       45564
# 5004      0.9042 0.2549 0.5429 594.0000       47694       45563
# 5005      0.9042 0.2549 0.5430 594.0000       47701       45556
# 5006      0.9042 0.2550 0.5430 594.0000       47702       45555
# 5007      0.9042 0.2550 0.5431 594.0000       47710       45547
# 5008      0.9042 0.2551 0.5431 594.0000       47711       45546
# 5009      0.9042 0.2551 0.5431 594.0000       47712       45545
# 5010      0.9042 0.2552 0.5431 594.0000       47713       45544
# 5011      0.9042 0.2552 0.5431 594.0000       47714       45543
# 5012      0.9042 0.2553 0.5431 594.0000       47715       45542
# 5013      0.9042 0.2553 0.5431 594.0000       47717       45540
# 5014      0.9042 0.2553 0.5431 594.0000       47718       45539
# 5015      0.9042 0.2553 0.5433 594.0000       47731       45526
# 5016      0.9042 0.2554 0.5433 594.0000       47732       45525
# 5017      0.9041 0.2554 0.5435 594.0000       47750       45507
# 5018      0.9041 0.2555 0.5435 594.0000       47751       45506
# 5019      0.9041 0.2555 0.5435 594.0000       47754       45503
# 5020      0.9041 0.2556 0.5435 594.0000       47755       45502
# 5021      0.9041 0.2556 0.5435 594.0000       47756       45501
# 5022      0.9041 0.2557 0.5435 594.0000       47757       45500
# 5023      0.9040 0.2557 0.5441 594.0000       47803       45454
# 5024      0.9040 0.2558 0.5441 594.0000       47804       45453
# 5025      0.9040 0.2558 0.5442 594.0000       47809       45448
# 5026      0.9040 0.2559 0.5442 594.0000       47810       45447
# 5027      0.9040 0.2559 0.5442 594.0000       47814       45443
# 5028      0.9040 0.2560 0.5442 594.0000       47815       45442
# 6001         0.5708          0.4292
# 6002         0.5709          0.4291
# 6003         0.5709          0.4291
# 6004         0.5711          0.4289
# 6005         0.5711          0.4289
# 6006         0.5711          0.4289
# 6007         0.5711          0.4289
# 6008         0.5715          0.4285
# 6009         0.5715          0.4285
# 6010         0.5715          0.4285
# 6011         0.5715          0.4285
# 6012         0.5718          0.4282
# 6013         0.5718          0.4282
# 6014         0.5718          0.4282
# 6015         0.5719          0.4281
# 6016         0.5721          0.4279
# 6017         0.5721          0.4279
# 6018         0.5724          0.4276
# 6019         0.5725          0.4275
# 6020         0.5725          0.4275
# 6021         0.5725          0.4275
# 6022         0.5725          0.4275
# 6023         0.5725          0.4275
# 6024         0.5732          0.4268
# 6025         0.5732          0.4268
# 6026         0.5734          0.4266
# 6027         0.5734          0.4266
# 6028         0.5737          0.4263
# 6029         0.5738          0.4262
# 6030         0.5739          0.4261
# 6031         0.5739          0.4261
# 6032         0.5741          0.4259
# 6033         0.5741          0.4259
# 6034         0.5742          0.4258
# 6035         0.5742          0.4258
# 6036         0.5742          0.4258
# 6037         0.5742          0.4258
# 6038         0.5745          0.4255
# 6039         0.5746          0.4254
# 6040         0.5747          0.4253
# 6041         0.5747          0.4253
# 6042         0.5749          0.4251
# 6043         0.5749          0.4251
# 6044         0.5750          0.4250
# 6045         0.5750          0.4250
# 6046         0.5751          0.4249
# 6047         0.5752          0.4248
# 6048         0.5754          0.4246
# 6049         0.5754          0.4246
# 6050         0.5755          0.4245
# 6051         0.5755          0.4245
# 6052         0.5755          0.4245
# 6053         0.5756          0.4244
# 6054         0.5756          0.4244
# 6055         0.5756          0.4244
# 6056         0.5758          0.4242
# 6057         0.5758          0.4242
# 6058         0.5759          0.4241
# 6059         0.5759          0.4241
# 6060         0.5760          0.4240
# 6061         0.5760          0.4240
# 6062         0.5760          0.4240
# 6063         0.5760          0.4240
# 6064         0.5761          0.4239
# 6065         0.5761          0.4239
# 6066         0.5763          0.4237
# 6067         0.5763          0.4237
# 6068         0.5763          0.4237
# 6069         0.5763          0.4237
# 6070         0.5765          0.4235
# 6071         0.5765          0.4235
# 6072         0.5765          0.4235
# 6073         0.5766          0.4234
# 6074         0.5766          0.4234
# 6075         0.5767          0.4233
# 6076         0.5767          0.4233
# 6077         0.5767          0.4233
# 6078         0.5768          0.4232
# 6079         0.5768          0.4232
# 6080         0.5769          0.4231
# 6081         0.5769          0.4231
# 6082         0.5770          0.4230
# 6083         0.5770          0.4230
# 6084         0.5772          0.4228
# 6085         0.5772          0.4228
# 6086         0.5773          0.4227
# 6087         0.5773          0.4227
# 6088         0.5775          0.4225
# 6089         0.5775          0.4225
# 6090         0.5778          0.4222
# 6091         0.5778          0.4222
# 6092         0.5780          0.4220
# 6093         0.5780          0.4220
# 6094         0.5781          0.4219
# 6095         0.5781          0.4219
# 6096         0.5782          0.4218
# 6097         0.5782          0.4218
# 6098         0.5782          0.4218
# 6099         0.5782          0.4218
# 6100         0.5783          0.4217
# 6101         0.5783          0.4217
# 6102         0.5783          0.4217
# 6103         0.5783          0.4217
# 6104         0.5784          0.4216
# 6105         0.5784          0.4216
# 6106         0.5788          0.4212
# 6107         0.5788          0.4212
# 6108         0.5789          0.4211
# 6109         0.5789          0.4211
# 6110         0.5789          0.4211
# 6111         0.5790          0.4210
# 6112         0.5793          0.4207
# 6113         0.5793          0.4207
# 6114         0.5793          0.4207
# 6115         0.5793          0.4207
# 6116         0.5795          0.4205
# 6117         0.5796          0.4204
# 6118         0.5796          0.4204
# 6119         0.5796          0.4204
# 6120         0.5796          0.4204
# 6121         0.5796          0.4204
# 6122         0.5798          0.4202
# 6123         0.5798          0.4202
# 6124         0.5800          0.4200
# 6125         0.5800          0.4200
# 6126         0.5800          0.4200
# 6127         0.5800          0.4200
# 6128         0.5801          0.4199
# 6129         0.5801          0.4199
# 6130         0.5802          0.4198
# 6131         0.5802          0.4198
# 6132         0.5803          0.4197
# 6133         0.5803          0.4197
# 6134         0.5803          0.4197
# 6135         0.5803          0.4197
# 6136         0.5804          0.4196
# 6137         0.5804          0.4196
# 6138         0.5804          0.4196
# 6139         0.5804          0.4196
# 6140         0.5805          0.4195
# 6141         0.5805          0.4195
# 6142         0.5805          0.4195
# 6143         0.5805          0.4195
# 6144         0.5806          0.4194
# 6145         0.5806          0.4194
# 6146         0.5809          0.4191
# 6147         0.5809          0.4191
# 6148         0.5810          0.4190
# 6149         0.5810          0.4190
# 6150         0.5811          0.4189
# 6151         0.5811          0.4189
# 6152         0.5811          0.4189
# 6153         0.5811          0.4189
# 6154         0.5812          0.4188
# 6155         0.5812          0.4188
# 6156         0.5814          0.4186
# 6157         0.5814          0.4186
# 6158         0.5816          0.4184
# 6159         0.5816          0.4184
# 6160         0.5817          0.4183
# 6161         0.5817          0.4183
# 6162         0.5817          0.4183
# 6163         0.5817          0.4183
# 6164         0.5819          0.4181
# 6165         0.5820          0.4180
# 6166         0.5820          0.4180
# 6167         0.5820          0.4180
# 6168         0.5820          0.4180
# 6169         0.5820          0.4180
# 6170         0.5821          0.4179
# 6171         0.5821          0.4179
# 6172         0.5822          0.4178
# 6173         0.5822          0.4178
# 6174         0.5822          0.4178
# 6175         0.5822          0.4178
# 6176         0.5823          0.4177
# 6177         0.5823          0.4177
# 6178         0.5823          0.4177
# 6179         0.5823          0.4177
# 6180         0.5823          0.4177
# 6181         0.5823          0.4177
# 6182         0.5824          0.4176
# 6183         0.5824          0.4176
# 6184         0.5824          0.4176
# 6185         0.5824          0.4176
# 6186         0.5825          0.4175
# 6187         0.5825          0.4175
# 6188         0.5825          0.4175
# 6189         0.5825          0.4175
# 6190         0.5825          0.4175
# 6191         0.5825          0.4175
# 6192         0.5828          0.4172
# 6193         0.5828          0.4172
# 6194         0.5828          0.4172
# 6195         0.5828          0.4172
# 6196         0.5833          0.4167
# 6197         0.5833          0.4167
# 6198         0.5833          0.4167
# 6199         0.5834          0.4166

# %%
inputs_train_with_ref_cat.to_csv('F:\\Codes\\Dataset\\Credit analysis\\loan data\\inputs_train_with_ref_cat.csv')

# %%
df_scorecard.to_csv('F:\\Codes\\Dataset\\Credit analysis\\loan data\\df_scorecard.csv')
